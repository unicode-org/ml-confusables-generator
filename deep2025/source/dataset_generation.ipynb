# %% [markdown]
# Dependencies:
# - qahirah
# - freetype
# - `vis_gen.py` from `source/vis_gen.py`

# %% [markdown]
# ## Download UnicodeData.txt file

# %%
import requests

url = "https://www.unicode.org/Public/UCD/latest/ucd/UnicodeData.txt"
response = requests.get(url)

# Save to file
with open("UnicodeData.txt", "w", encoding="utf-8") as f:
    f.write(response.text)

print("Downloaded UnicodeData.txt")
# Out:
# Downloaded UnicodeData.txt

# %% [markdown]
# ## Download Blocks.txt file

# %%
import requests

url = "https://www.unicode.org/Public/UCD/latest/ucd/Blocks.txt"
response = requests.get(url)

# Save to file
with open("Blocks.txt", "w", encoding="utf-8") as f:
    f.write(response.text)

print("Downloaded Blocks.txt")
# Out:
# Downloaded Blocks.txt

# %% [markdown]
# ## Extract the left-to-right scripts

# %%
alphabets = {}

with open('/content/Blocks.txt', 'r') as infile:
  for line in infile.readlines():
    # Skip the comments and new line
    if line[0]=='#' or line[0]=='\n':
      continue

    # Extract the codepoints and the script name
    parts = line.split(";")
    codepoints = parts[0]
    script = parts[1].strip()

    # Separate the starting and ending codepoints
    start_codepoint = codepoints.split('..')[0]
    end_codepoint = codepoints.split('..')[1]

    if any(key in script.lower() for key in ('latin', 'cyrillic', 'armenian',
                                             'greek', 'coptic', 'ipa',
                                             'spacing', 'diacritical')):
      alphabets[script] = {
          'start': start_codepoint,
          'end': end_codepoint
      }

# Sort the dictionary
alphabets = dict(sorted(alphabets.items()))

# %%
alphabets
# Out:
# {'Ancient Greek Musical Notation': {'start': '1D200', 'end': '1D24F'},
#  'Ancient Greek Numbers': {'start': '10140', 'end': '1018F'},
#  'Armenian': {'start': '0530', 'end': '058F'},
#  'Basic Latin': {'start': '0000', 'end': '007F'},
#  'Combining Diacritical Marks': {'start': '0300', 'end': '036F'},
#  'Combining Diacritical Marks Extended': {'start': '1AB0', 'end': '1AFF'},
#  'Combining Diacritical Marks Supplement': {'start': '1DC0', 'end': '1DFF'},
#  'Combining Diacritical Marks for Symbols': {'start': '20D0', 'end': '20FF'},
#  'Coptic': {'start': '2C80', 'end': '2CFF'},
#  'Coptic Epact Numbers': {'start': '102E0', 'end': '102FF'},
#  'Cyrillic': {'start': '0400', 'end': '04FF'},
#  'Cyrillic Extended-A': {'start': '2DE0', 'end': '2DFF'},
#  'Cyrillic Extended-B': {'start': 'A640', 'end': 'A69F'},
#  'Cyrillic Extended-C': {'start': '1C80', 'end': '1C8F'},
#  'Cyrillic Extended-D': {'start': '1E030', 'end': '1E08F'},
#  'Cyrillic Supplement': {'start': '0500', 'end': '052F'},
#  'Greek Extended': {'start': '1F00', 'end': '1FFF'},
#  'Greek and Coptic': {'start': '0370', 'end': '03FF'},
#  'IPA Extensions': {'start': '0250', 'end': '02AF'},
#  'Latin Extended Additional': {'start': '1E00', 'end': '1EFF'},
#  'Latin Extended-A': {'start': '0100', 'end': '017F'},
#  'Latin Extended-B': {'start': '0180', 'end': '024F'},
#  'Latin Extended-C': {'start': '2C60', 'end': '2C7F'},
#  'Latin Extended-D': {'start': 'A720', 'end': 'A7FF'},
#  'Latin Extended-E': {'start': 'AB30', 'end': 'AB6F'},
#  'Latin Extended-F': {'start': '10780', 'end': '107BF'},
#  'Latin Extended-G': {'start': '1DF00', 'end': '1DFFF'},
#  'Latin-1 Supplement': {'start': '0080', 'end': '00FF'},
#  'Spacing Modifier Letters': {'start': '02B0', 'end': '02FF'}}

# %% [markdown]
# ## Extract the codepoints

# %%
import os

# Acceptable general categories
renderable_categories = {
    'Lu', 'Ll', 'Lt', 'Lm', 'Lo',  # Letters
    'Mn', 'Mc', 'Me',              # Marks
    'Nd', 'Nl', 'No',              # Numbers
    'Pc', 'Pd', 'Ps', 'Pe', 'Pi', 'Pf', 'Po',  # Punctuation
    'Sm', 'Sc', 'Sk', 'So',        # Symbols
    # 'Zs'                           # Space separator
}

scripts_dir = '/content/scripts'
os.makedirs(scripts_dir, exist_ok=True)

for script, range_info in alphabets.items():
  start_codepoint = range_info['start']
  end_codepoint = range_info['end']

  start_int = int(start_codepoint, 16)
  end_int = int(end_codepoint, 16)

  with open('/content/UnicodeData.txt' ,'r') as infile, open(os.path.join(scripts_dir,f'{script}.txt'),'w') as outfile:
    for line in infile.readlines():
      parts = line.split(';')

      if len(parts)<3:
        continue

      codepoint, name, category = parts[0], parts[1], parts[2]
      cp_int = int(codepoint, 16)

      if start_int<=cp_int<=end_int:
        if category in renderable_categories:
          outfile.write('U+'+codepoint+'\n')

# %%
# Shows the fonts installed in the system
# !fc-list
# Out:
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf: Liberation Sans Narrow:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf: Liberation Sans:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf: Liberation Mono:style=Bold Italic
# /usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf: Liberation Serif:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf: Liberation Mono:style=Bold
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf: Liberation Sans Narrow:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf: Liberation Serif:style=Bold
# /usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf: Liberation Mono:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf: Liberation Sans:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf: Liberation Serif:style=Bold Italic
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf: Liberation Sans Narrow:style=Bold Italic
# /usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf: Liberation Mono:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf: Liberation Sans:style=Bold Italic
# /usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf: Liberation Serif:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf: Liberation Sans Narrow:style=Bold
# /usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf: Liberation Sans:style=Bold
# /usr/share/fonts/truetype/humor-sans/Humor-Sans.ttf: Humor Sans:style=Regular

# %%
# Codepoints which couldn't be rendered before

excluded_codepoints = [
    # Combining Diacritical Marks Extended
    *["U+{:04X}".format(cp) for cp in range(0x1AC1, 0x1ACF)],

    # Combining Diacritical Marks for Symbols
    *["U+{:04X}".format(cp) for cp in range(0x20D0, 0x2100)],
    "U+1DFA",

    # Ancient Greek Musical Notation
    *["U+{:04X}".format(cp) for cp in range(0x1D200, 0x1D245)],

    # Ancient Greek Numbers
    *["U+{:04X}".format(cp) for cp in range(0x10140, 0x1018B)],

    # Armenian
    *["U+{:04X}".format(cp) for cp in range(0x0530, 0x0590)],

    # Coptic
    *["U+{:04X}".format(cp) for cp in range(0x2C80, 0x2D00)],

    # Coptic Epact Numbers
    *["U+{:04X}".format(cp) for cp in range(0x102E0, 0x10300)],

    # Cyrillic Extended-C
    "U+1C89", "U+1C8A",

    # Cyrillic Extended-D
    *["U+{:04X}".format(cp) for cp in range(0x1E030, 0x1E08F)],

    # Latin Extended-D (some scattered, some range)
    "U+A7C0", "U+A7C1",
    *["U+{:04X}".format(cp) for cp in range(0xA7CB, 0xA7F4)],

    # Latin Extended-F
    *["U+{:04X}".format(cp) for cp in range(0x10780, 0x107C0)],

    # Latin Extended-G (assumed typo above, but it's Latin Extended-G)
    *["U+{:04X}".format(cp) for cp in range(0x1DF00, 0x1DF1F)],
    *["U+{:04X}".format(cp) for cp in range(0x1DF25, 0x1DF2A)],
]

len(excluded_codepoints)
# Out:
# 703

# %% [markdown]
# ## Download the noto fonts

# %%
# !git clone https://github.com/notofonts/notofonts.github.io.git
# Out:
# Cloning into 'notofonts.github.io'...
# remote: Enumerating objects: 45290, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 45290 (delta 86), reused 75 (delta 75), pack-reused 45185 (from 3)
# Receiving objects: 100% (45290/45290), 1.33 GiB | 23.34 MiB/s, done.
# Resolving deltas: 100% (30187/30187), done.
# Updating files: 100% (11977/11977), done.

# %% [markdown]
# ## Download the Microsoft fonts

# %%
# !git clone https://github.com/pjobson/Microsoft-Fonts.git

# %% [markdown]
# ## Extract the zip files

# %%
# import os
# import gzip
# import shutil

# windows_font_dir = '/content/Microsoft-Fonts/2021 - Windows 11/ttf'

# for filename in os.listdir(windows_font_dir):
#     if filename.endswith('.ttf.gz'):
#         gz_path = os.path.join(windows_font_dir, filename)
#         ttf_path = os.path.join(windows_font_dir, filename[:-3])  # remove .gz

#         # Extract .ttf.gz to .ttf
#         with gzip.open(gz_path, 'rb') as f_in, open(ttf_path, 'wb') as f_out:
#             shutil.copyfileobj(f_in, f_out)

#         # Delete the .ttf.gz file
#         os.remove(gz_path)

# print("Extraction complete and original .ttf.gz files deleted.")

# %% [markdown]
# ## Create the codepoint to font mapping

# %%
root_dirs = ["/content/notofonts.github.io/fonts"]
font_paths = []
for root_dir in root_dirs:
  for root, dirs, files in os.walk(root_dir):
      for file in files:
          if file.endswith('.ttf'):
              font_paths.append(os.path.join(root, file))

# %% [markdown]
# Only keep the regular or basic fonts without any styles like Bold, Italic, etc.

# %%
import os
from collections import defaultdict

# A map from font family name to its candidate font files
font_family_map = defaultdict(list)

def extract_family_name(path):
    filename = os.path.basename(path)
    # Remove style part like -Bold, -Thin, etc.
    name = filename.replace('.ttf', '')
    name = name.split('-')[0]  # e.g., NotoSansOriya-Regular → NotoSansOriya
    return name

# Group fonts by base family name
for path in font_paths:
    family = extract_family_name(path)
    font_family_map[family].append(path)

# Now pick the 'basic' font: prefer Regular.ttf, else first available
pruned_fonts = []

for family, paths in font_family_map.items():
    regular_fonts = [p for p in paths if 'Regular.ttf' in p]
    if regular_fonts:
        pruned_fonts.append(regular_fonts[0])
    else:
        pruned_fonts.append(paths[0])  # fallback

# Optional: sort the result
pruned_fonts.sort()

# Final output
for font in pruned_fonts:
    print(font)
# Out:
# /content/notofonts.github.io/fonts/NotoFangsongKSSRotated/googlefonts/ttf/NotoFangsongKSSRotated-Regular.ttf
# /content/notofonts.github.io/fonts/NotoFangsongKSSVertical/googlefonts/ttf/NotoFangsongKSSVertical-Regular.ttf
# /content/notofonts.github.io/fonts/NotoKufiArabic/googlefonts/ttf/NotoKufiArabic-Regular.ttf
# /content/notofonts.github.io/fonts/Not
wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTamil/googlefonts/ttf/NotoSerifTamil-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifTamil/googlefonts/variable-ttf/NotoSerifTamil[wdth,wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTamil/unhinted/slim-variable-ttf/NotoSerifTamil[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTangut/googlefonts/ttf/NotoSerifTangut-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifTelugu/googlefonts/ttf/NotoSerifTelugu-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifTelugu/googlefonts/variable-ttf/NotoSerifTelugu[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTest/googlefonts/slim-variable-ttf/NotoSerifTest[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTest/googlefonts/ttf/NotoSerifTest-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifThai/googlefonts/ttf/NotoSerifThai-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifThai/googlefonts/variable-ttf/NotoSerifThai[wdth,wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifThai/unhinted/slim-variable-ttf/NotoSerifThai[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTibetan/googlefonts/slim-variable-ttf/NotoSerifTibetan[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifTibetan/googlefonts/ttf/NotoSerifTibetan-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifToto/googlefonts/ttf/NotoSerifToto-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifToto/googlefonts/variable-ttf/NotoSerifToto[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifVithkuqi/googlefonts/ttf/NotoSerifVithkuqi-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifVithkuqi/googlefonts/variable-ttf/NotoSerifVithkuqi[wght].ttf
# /content/notofonts.github.io/fonts/NotoSerifYezidi/googlefonts/ttf/NotoSerifYezidi-Regular.ttf
# /content/notofonts.github.io/fonts/NotoSerifYezidi/googlefonts/variable-ttf/NotoSerifYezidi[wght].ttf
# /content/notofonts.github.io/fonts/NotoTraditionalNushu/googlefonts/ttf/NotoTraditionalNushu-Regular.ttf
# /content/notofonts.github.io/fonts/NotoTraditionalNushu/googlefonts/variable-ttf/NotoTraditionalNushu[wght].ttf
# /content/notofonts.github.io/fonts/NotoZnamennyMusicalNotation/googlefonts/ttf/NotoZnamennyMusicalNotation-Regular.ttf

# %% [markdown]
# Now install the fonts in the system

# %%
import os
import subprocess
from glob import glob

FONT_SOURCE_DIR = "/content/notofonts.github.io/fonts"
FONT_INSTALL_DIR = "/usr/share/fonts/truetype/custom/"

os.makedirs(FONT_INSTALL_DIR, exist_ok=True)

# Get all .ttf files recursively
ttf_files = glob(os.path.join(FONT_SOURCE_DIR, "**/*.ttf"), recursive=True)

# Skip fonts with variable axes like [wght] or [wdth,wght]
def is_variable_font(ttf_path):
    basename = os.path.basename(ttf_path)
    return "[" in basename and "]" in basename

for ttf_file in ttf_files:
    if is_variable_font(ttf_file):
        print(f"Skipping variable font: {ttf_file}")
        continue

    filename = os.path.basename(ttf_file)
    installed_path = os.path.join(FONT_INSTALL_DIR, filename)
    subprocess.run(["cp", ttf_file, installed_path])

# Update font cache
subprocess.run(["fc-cache", "-fv"])
# Out:
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKawi/googlefonts/variable-ttf/NotoSansKawi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKawi/unhinted/slim-variable-ttf/NotoSansKawi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKawi/unhinted/variable-ttf/NotoSansKawi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKawi/full/slim-variable-ttf/NotoSansKawi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKawi/full/variable-ttf/NotoSansKawi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/googlefonts/variable-ttf/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/googlefonts/variable/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/unhinted/slim-variable-ttf/NotoSansOriya[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/unhinted/variable-ttf/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/unhinted/variable/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/full/slim-variable-ttf/NotoSansOriya[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/full/variable-ttf/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansOriya/full/variable/NotoSansOriya[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKayahLi/googlefonts/variable-ttf/NotoSansKayahLi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSansKayahLi/unhinted/slim-variable-ttf/NotoSansKayahLi[wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSans
ght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSerifTamil/full/variable-ttf/NotoSerifTamil-Italic[wdth,wght].ttf
# Skipping variable font: /content/notofonts.github.io/fonts/NotoSerifTamil/full/variable-ttf/NotoSerifTamil[wdth,wght].ttf
# CompletedProcess(args=['fc-cache', '-fv'], returncode=0)

# %% [markdown]
# Verify the installation

# %%
# !fc-list
# Out:
# /usr/share/fonts/truetype/custom/NotoSansCanadianAboriginal-Thin.ttf: Noto Sans Canadian Aboriginal,Noto Sans Canadian Aboriginal Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansKannadaUI-Black.ttf: Noto Sans Kannada UI,Noto Sans Kannada UI Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhi-ExtraCondensedThin.ttf: Noto Sans Gurmukhi ExtraCondensed,Noto Sans Gurmukhi ExtraCondensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-ExtraCondensedThinItalic.ttf: Noto Serif,Noto Serif ExtraCondensed Thin:style=ExtraCondensed Thin Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifThai-Light.ttf: Noto Serif Thai,Noto Serif Thai Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-SemiCondensedMedium.ttf: Noto Serif,Noto Serif SemiCondensed Medium:style=SemiCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansKannada-SemiCondensedSemiBold.ttf: Noto Sans Kannada,Noto Sans Kannada SemiCondensed SemiBold:style=SemiCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-Thin.ttf: Noto Serif Ethiopic,Noto Serif Ethiopic Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagariUI-ExtraBold.ttf: Noto Sans Devanagari UI,Noto Sans Devanagari UI ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansBalinese-Regular.ttf: Noto Sans Balinese:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansSogdian-Regular.ttf: Noto Sans Sogdian:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-SemiCondensedExtraLight.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI SemiCondensed ExtraLight:style=SemiCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedMedium.ttf: Noto Sans,Noto Sans ExtraCondensed Medium:style=ExtraCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansTifinaghAzawagh-Regular.ttf: Noto Sans Tifinagh Azawagh:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-SemiCondensedExtraLight.ttf: Noto Sans Malayalam SemiCondensed,Noto Sans Malayalam SemiCondensed ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-CondensedMedium.ttf: Noto Sans Tamil Condensed,Noto Sans Tamil Condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-CondensedLightItalic.ttf: Noto Serif Display Condensed,Noto Serif Display Condensed Light:style=Light Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifSinhala-ExtraCondensedExtraBold.ttf: Noto Serif Sinhala ExtraCondensed,Noto Serif Sinhala ExtraCondensed ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansHebrew-SemiCondensedExtraBold.ttf: Noto Sans Hebrew,Noto Sans Hebrew SemiCondensed ExtraBold:style=SemiCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-ExtraCondensedBold.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI XCn:style=ExtraCondensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSansThaiLooped-ExtraBold.ttf: Noto Sans Thai Looped,Noto Sans Thai Looped ExtraBold:style=Extrabold,Regular
# /usr/share/fonts/truetype/custom/NotoSansMono-Regular.ttf: Noto Sans Mono:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansCham-Light.ttf: Noto Sans Cham,Noto Sans Cham Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-CondensedExtraBold.ttf: Noto Serif,Noto Serif Condensed ExtraBold:style=Condensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansThai-ExtraCondensedExtraBold.ttf: Noto Sans Thai,Noto Sans Thai ExtCond ExtBd:style=ExtraCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-ExtraCondensedBlack.ttf: Noto Sans Gujarati,Noto Sans Gujarati ExtraCondensed Black:style=ExtraCondensed Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-ExtraCondensedSemiBold.ttf: Noto Sans Armenian,Noto Sans Armenian ExtraCondensed SemiBold:style=ExtraCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansLaoLooped-CondensedMedium.ttf: Noto Sans Lao Looped Condensed,Noto Sans Lao Looped Condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-CondensedBold.ttf: Noto Serif Display Condensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifKhmer-ExtraBold.ttf: Noto Serif Khmer,Noto Serif Khmer ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansThai-CondensedLight.ttf: Noto Sans Thai,Noto Sans Thai Cond Light:style=Condensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhiUI-Light.ttf: Noto Sans Gurmukhi UI,Noto Sans Gurmukhi UI Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujaratiUI-Bold.ttf: Noto Sans Gujarati UI:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifTibetan-Thin.ttf: Noto Serif Tibetan,Noto Serif Tibetan Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansKhmer-ExtraLight.ttf: Noto Sans Khmer,Noto Sans Khmer ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-Condensed.ttf: Noto Sans Tamil UI Condensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifMyanmar-SemiCondensedSemiBold.ttf: Noto Serif Myanmar SemiCondensed,Noto Serif Myanmar SemiCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansMyanmar
style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansZanabazarSquare-Regular.ttf: Noto Sans Zanabazar Square:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansBhaiksuki-Regular.ttf: Noto Sans Bhaiksuki:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansVithkuqi-Regular.ttf: Noto Sans Vithkuqi:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansLaoLooped-SemiCondensedExtraLight.ttf: Noto Sans Lao Looped SemiCondensed,Noto Sans Lao Looped SemiCondensed ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf: Liberation Sans Narrow:style=Italic
# /usr/share/fonts/truetype/custom/NotoSansBengaliUI-SemiBold.ttf: Noto Sans Bengali UI,Noto Sans Bengali UI SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhiUI-Medium.ttf: Noto Sans Gurmukhi UI,Noto Sans Gurmukhi UI Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-Medium.ttf: Noto Sans Devanagari,Noto Sans Devanagari Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-Thin.ttf: Noto Sans Tamil UI,Noto Sans Tamil UI Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerifArmenian-SemiCondensedThin.ttf: Noto Serif Armenian,Noto Serif Armenian SemiCondensed Thin:style=SemiCondensed Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabic-ExtraCondensedExtraBold.ttf: Noto Sans Arabic,Noto Sans Arabic ExtCond ExtBd:style=ExtraCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-Light.ttf: Noto Serif Ethiopic,Noto Serif Ethiopic Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-Black.ttf: Noto Serif,Noto Serif Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSans-SemiCondensedExtraLightItalic.ttf: Noto Sans,Noto Sans SemiCondensed ExtraLight:style=SemiCondensed ExtraLight Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansDevanagariUI-ExtraLight.ttf: Noto Sans Devanagari UI,Noto Sans Devanagari UI ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-SemiCondensedMedium.ttf: Noto Sans Gujarati,Noto Sans Gujarati SemiCondensed Medium:style=SemiCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-ExtraCondensedMedium.ttf: Noto Serif Thai,Noto Serif Thai ExtraCondensed Medium:style=ExtraCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagariUI-SemiCondensedThin.ttf: Noto Sans Devanagari UI SemiCondensed,Noto Sans Devanagari UI SemiCondensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansLao-ExtraLight.ttf: Noto Sans Lao,Noto Sans Lao ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansLaoLooped-CondensedLight.ttf: Noto Sans Lao Looped Condensed,Noto Sans Lao Looped Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansHebrew-ExtraCondensed.ttf: Noto Sans Hebrew,Noto Sans Hebrew ExtraCondensed:style=ExtraCondensed,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-Medium.ttf: Noto Serif Display,Noto Serif Display Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-ExtraCondensedExtraLight.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI ExtraCondensed ExtraLight:style=ExtraCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansElymaic-Regular.ttf: Noto Sans Elymaic:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansEthiopic-SemiCondensed.ttf: Noto Sans Ethiopic SemiCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansSundanese-Bold.ttf: Noto Sans Sundanese:style=Bold
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-SemiCondensedSemiBold.ttf: Noto Sans Devanagari,Noto Sans Devanagari SemiCondensed SemiBold:style=SemiCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujaratiUI-SemiCondensedSemiBold.ttf: Noto Sans Gujarati UI,Noto Sans Gujarati UI SemiCondensed SemiBold:style=SemiCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagariUI-SemiCondensed.ttf: Noto Sans Devanagari UI SemiCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSans-Thin.ttf: Noto Sans,Noto Sans Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhi-Bold.ttf: Noto Sans Gurmukhi:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifThai-SemiCondensedExtraBold.ttf: Noto Serif Thai,Noto Serif Thai SemiCondensed ExtraBold:style=SemiCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansKhmer-CondensedExtraBold.ttf: Noto Sans Khmer,Noto Sans Khmer Condensed ExtraBold:style=Condensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagariUI-Thin.ttf: Noto Sans Devanagari UI,Noto Sans Devanagari UI Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabic-CondensedExtraLight.ttf: Noto Sans Arabic,Noto Sans Arabic Cond ExtLt:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansSyriacWestern-Thin.ttf: Noto Sans Syriac Western,Noto Sans Syriac Western Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansTelugu-UI-VF.ttf: Noto Sans Telugu UI:style=SemiBold
# /usr/share/fonts/truetype/custom/NotoSansMono-SemiCondensedThin.ttf: Noto Sans Mono,Noto Sans Mono SemiCondensed Thin:style=SemiCondensed Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerifGeorgian-CondensedBold.ttf: Noto Serif Georgian,Noto Serif Georgian Cn:style=Condensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSansTelugu-ExtraCondensedBold.ttf: Noto Sans Telugu,Noto Sans Telugu ExtraCondensed:style=ExtraCondensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSansLisu-Bold.ttf: Noto Sans Lisu:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifArmenian-CondensedExtraLight.ttf: Noto Serif Armenian,Noto Serif Armenian Condensed ExtraLight:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifMyanmar-CondensedBlack.ttf: Noto Serif Myanmar Condensed,Noto Serif Myanmar Condensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansKannadaUI-ExtraCondensedBold.ttf: Noto Sans Kannada UI,Noto Sans Kannada UI ExtraCondensed:style=ExtraCondensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-Condensed.ttf: Noto Serif Ethiopic Condensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansArabic-ExtraBold.ttf: Noto Sans Arabic,Noto Sans Arabic ExtBd:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-Regular.ttf: Noto Sans Tamil UI:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansTelugu-ExtraCondensedExtraLight.ttf: Noto Sans Telugu,Noto Sans Telugu ExtraCondensed ExtraLight:style=ExtraCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-ExtraCondensed.ttf: Noto Serif Display ExtraCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-ExtraCondensedSemiBold.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI ExtraCondensed SemiBold:style=ExtraCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-SemiCondensedThin.ttf: Noto Sans Malayalam SemiCondensed,Noto Sans Malayalam SemiCondensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansKawi-Regular.ttf: Noto Sans Kawi:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansSignWriting-Regular.ttf: Noto Sans SignWriting:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-ExtraCondensedBlack.ttf: Noto Sans Tamil ExtraCondensed,Noto Sans Tamil ExtraCondensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSerifHebrew-Regular.ttf: Noto Serif Hebrew:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansMono-CondensedLight.ttf: Noto Sans Mono,Noto Sans Mono Condensed Light:style=Condensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-Light.ttf: Noto Serif Display,Noto Serif Display Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifArmenian-CondensedThin.ttf: Noto Serif Armenian,Noto Serif Armenian Condensed Thin:style=Condensed Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedLightItalic.ttf: Noto Sans,Noto Sans ExtraCondensed Light:style=ExtraCondensed Light Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansHanifiRohingya-Regular.ttf: Noto Sans Hanifi Rohingya:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-Medium.ttf: Noto Sans Armenian,Noto Sans Armenian Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-CondensedItalic.ttf: Noto Serif Display Condensed:style=Italic
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-CondensedLight.ttf: Noto Serif Ethiopic Condensed,Noto Serif Ethiopic Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansMedefaidrin-Bold.ttf: Noto Sans Medefaidrin:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifBengali-SemiBold.ttf: Noto Serif Bengali,Noto Serif Bengali SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-CondensedThin.ttf: Noto Sans Tamil UI Condensed,Noto Sans Tamil UI Condensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-Black.ttf: Noto Sans Tamil UI,Noto Sans Tamil UI Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-SemiCondensedBold.ttf: Noto Sans Tamil SemiCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifBengali-CondensedBlack.ttf: Noto Serif Bengali Condensed,Noto Serif Bengali Condensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansMyanmar-CondensedBold.ttf: Noto Sans Myanmar Condensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSansCanadianAboriginal-SemiBold.ttf: Noto Sans Canadian Aboriginal,Noto Sans Canadian Aboriginal SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhiUI-ExtraLight.ttf: Noto Sans Gurmukhi UI,Noto Sans Gurmukhi UI ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansTelugu-Condensed.ttf: Noto Sans Telugu,Noto Sans Telugu Condensed:style=Condensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansThaiLooped-Light.ttf: Noto Sans Thai Looped,Noto Sans Thai Looped Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDevanagari-ExtraLight.ttf: Noto Serif Devanagari,Noto Serif Devanagari ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifLao-ExtraCondensed.ttf: Noto Serif Lao ExtraCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-SemiCondensedMedium.ttf: Noto Sans Armenian,Noto Sans Armenian SemiCondensed Medium:style=SemiCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansLaoLooped-SemiCondensedBold.ttf: Noto Sans Lao Looped SemiCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifLao-SemiCondensedExtraLight.ttf: Noto Serif Lao SemiCondensed,Noto Serif Lao SemiCondensed ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensed.ttf: Noto Sans,Noto Sans ExtraCondensed:style=ExtraCondensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhala
r/share/fonts/truetype/liberation/LiberationSans-Regular.ttf: Liberation Sans:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansJavanese-Regular.ttf: Noto Sans Javanese:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifTibetan-Medium.ttf: Noto Serif Tibetan,Noto Serif Tibetan Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-Condensed.ttf: Noto Sans Gujarati,Noto Sans Gujarati Condensed:style=Condensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansKhojki-Regular.ttf: Noto Sans Khojki:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansKannada-Thin.ttf: Noto Sans Kannada,Noto Sans Kannada Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansOriya-CondensedBold.ttf: Noto Sans Oriya,Noto Sans Oriya Cond Bold:style=Condensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-SemiCondensedBoldItalic.ttf: Noto Serif Display SemiCondensed:style=Bold Italic
# /usr/share/fonts/truetype/custom/NotoSansHebrew-CondensedBlack.ttf: Noto Sans Hebrew,Noto Sans Hebrew Condensed Black:style=Condensed Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-CondensedSemiBold.ttf: Noto Sans Malayalam Condensed,Noto Sans Malayalam Condensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansKannadaUI-Light.ttf: Noto Sans Kannada UI,Noto Sans Kannada UI Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansKhmer-ExtraCondensedMedium.ttf: Noto Sans Khmer,Noto Sans Khmer ExtraCondensed Medium:style=ExtraCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-Regular.ttf: Noto Serif Thai:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-Thin.ttf: Noto Serif Thai,Noto Serif Thai Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansThai-Medium.ttf: Noto Sans Thai,Noto Sans Thai Med:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSans-CondensedExtraBoldItalic.ttf: Noto Sans,Noto Sans Condensed ExtraBold:style=Condensed ExtraBold Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansLaoLooped-Thin.ttf: Noto Sans Lao Looped,Noto Sans Lao Looped Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedThinItalic.ttf: Noto Sans,Noto Sans ExtraCondensed Thin:style=ExtraCondensed Thin Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansGeorgian-CondensedThin.ttf: Noto Sans Georgian,Noto Sans Georgian Condensed Thin:style=Condensed Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-SemiCondensed.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI SmCn:style=SemiCondensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-UI-VF.ttf: Noto Sans Tamil UI:style=SemiBold
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-CondensedLight.ttf: Noto Sans Malayalam Condensed,Noto Sans Malayalam Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-ExtraCondensedLight.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI ExtraCondensed Light:style=ExtraCondensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansGurmukhiUI-Black.ttf: Noto Sans Gurmukhi UI,Noto Sans Gurmukhi UI Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-ExtraCondensedThin.ttf: Noto Sans Armenian,Noto Sans Armenian ExtraCondensed Thin:style=ExtraCondensed Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-ExtraCondensedBold.ttf: Noto Sans Tamil UI ExtraCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifHebrew-ExtraCondensedMedium.ttf: Noto Serif Hebrew,Noto Serif Hebrew ExtraCondensed Medium:style=ExtraCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-Condensed.ttf: Noto Serif Thai,Noto Serif Thai Condensed:style=Condensed,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-SemiCondensedExtraBold.ttf: Noto Serif,Noto Serif SemiCondensed ExtraBold:style=SemiCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-SemiCondensedSemiBold.ttf: Noto Sans Tamil SemiCondensed,Noto Sans Tamil SemiCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansCoptic-Regular.ttf: Noto Sans Coptic:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-Light.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-Black.ttf: Noto Sans Tamil,Noto Sans Tamil Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSerifTamil-Light.ttf: Noto Serif Tamil,Noto Serif Tamil Light:style=Light,Regular
# /usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf: Liberation Mono:style=Bold Italic
# /usr/share/fonts/truetype/custom/NotoSerifMalayalam-Bold.ttf: Noto Serif Malayalam:style=Bold
# /usr/share/fonts/truetype/custom/NotoSansDeseret-Regular.ttf: Noto Sans Deseret:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-ExtraCondensedSemiBold.ttf: Noto Serif Thai,Noto Serif Thai ExtraCondensed SemiBold:style=ExtraCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansBengaliUI-SemiCondensed.ttf: Noto Sans Bengali UI SemiCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansArabic-Black.ttf: Noto Sans Arabic,Noto Sans Arabic Blk:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-CondensedExtraLight.ttf: Noto Sans Devanagari,Noto Sans Devanagari Condensed ExtraLight:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-ExtraLight.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI XLt:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedLight.ttf: Noto Sans,Noto Sans ExtraCondensed Light:style=ExtraCondensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDevanagari-CondensedLight.ttf: Noto Serif Devanagari,Noto Serif Devanagari Condensed Light:style=Condensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansElbasan-Regular.ttf: Noto Sans Elbasan:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifTamil-ExtraCondensedMediumItalic.ttf: Noto Serif Tamil ExtraCondensed,Noto Serif Tamil ExtraCondensed Medium:style=Medium Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-SemiCondensedExtraLight.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI SmCn XLt:style=SemiCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-CondensedExtraBold.ttf: Noto Sans Gujarati,Noto Sans Gujarati Condensed ExtraBold:style=Condensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-CondensedMedium.ttf: Noto Sans Tamil UI Condensed,Noto Sans Tamil UI Condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-Medium.ttf: Noto Sans Tamil UI,Noto Sans Tamil UI Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoRashiHebrew-Light.ttf: Noto Rashi Hebrew,Noto Rashi Hebrew Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-Condensed.ttf: Noto Sans Devanagari,Noto Sans Devanagari Condensed:style=Condensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-Bold.ttf: Noto Sans Armenian:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-CondensedSemiBoldItalic.ttf: Noto Serif Display Condensed,Noto Serif Display Condensed SemiBold:style=SemiBold Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifArmenian-ExtraLight.ttf: Noto Serif Armenian,Noto Serif Armenian ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-CondensedMedium.ttf: Noto Sans Devanagari,Noto Sans Devanagari Condensed Medium:style=Condensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansCham-ExtraLight.ttf: Noto Sans Cham,Noto Sans Cham ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedSemiBoldItalic.ttf: Noto Sans,Noto Sans ExtraCondensed SemiBold:style=ExtraCondensed SemiBold Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifSinhala-Regular.ttf: Noto Serif Sinhala:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-SemiCondensedSemiBold.ttf: Noto Sans Malayalam SemiCondensed,Noto Sans Malayalam SemiCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamilUI-SemiBold.ttf: Noto Sans Tamil UI,Noto Sans Tamil UI SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansHebrew-CondensedMedium.ttf: Noto Sans Hebrew,Noto Sans Hebrew Condensed Medium:style=Condensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansThaiLooped-ExtraCondensedSemiBold.ttf: Noto Sans Thai Looped ExtraCondensed,Noto Sans Thai Looped ExtraCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansLao-SemiCondensedBlack.ttf: Noto Sans Lao SemiCondensed,Noto Sans Lao SemiCondensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSerifSinhala-Medium.ttf: Noto Serif Sinhala,Noto Serif Sinhala Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansMyanmar-CondensedLight.ttf: Noto Sans Myanmar Condensed,Noto Sans Myanmar Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifHebrew-ExtraCondensedSemiBold.ttf: Noto Serif Hebrew,Noto Serif Hebrew ExtraCondensed SemiBold:style=ExtraCondensed SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansLao-ExtraCondensedMedium.ttf: Noto Sans Lao ExtraCondensed,Noto Sans Lao ExtraCondensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujaratiUI-CondensedExtraBold.ttf: Noto Sans Gujarati UI,Noto Sans Gujarati UI Condensed ExtraBold:style=Condensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-ExtraCondensedExtraBold.ttf: Noto Serif Ethiopic ExtraCondensed,Noto Serif Ethiopic ExtraCondensed ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansThai-Regular.ttf: Noto Sans Thai:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhalaUI-CondensedMedium.ttf: Noto Sans Sinhala UI Condensed,Noto Sans Sinhala UI Condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ThinItalic.ttf: Noto Sans,Noto Sans Thin:style=Thin Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansLao-ExtraCondensedLight.ttf: Noto Sans Lao ExtraCondensed,Noto Sans Lao ExtraCondensed Light:style=Light,Regular
# /usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf: Liberation Serif:style=Italic
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-CondensedBold.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI Condensed:style=Condensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSansGurmukhi-SemiBold.ttf: Noto Sans Gurmukhi,Noto Sans Gurmukhi SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-ExtraLight.ttf: Noto Serif Display,Noto Serif Display ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-CondensedExtraLight.ttf: Noto Serif,Noto Serif Condensed ExtraLight:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifBengali-CondensedMedium.ttf: Noto Serif Bengali Condensed,Noto Serif Bengali Condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansKannada-UI-VF.ttf: Noto Sans Kannada UI
# /usr/share/fonts/truetype/custom/NotoSansLao-CondensedThin.ttf: Noto Sans Lao Condensed,Noto Sans Lao Condensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-Sem
condensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifDevanagari-Black.ttf: Noto Serif Devanagari,Noto Serif Devanagari Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansTagalog-Regular.ttf: Noto Sans Tagalog:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifHebrew-CondensedLight.ttf: Noto Serif Hebrew,Noto Serif Hebrew Condensed Light:style=Condensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansGeorgian-SemiCondensedBlack.ttf: Noto Sans Georgian,Noto Sans Georgian SemiCondensed Black:style=SemiCondensed Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansMedefaidrin-Medium.ttf: Noto Sans Medefaidrin,Noto Sans Medefaidrin Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-ExtraCondensedBold.ttf: Noto Sans Armenian,Noto Sans Armenian ExtraCondensed:style=ExtraCondensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSerifDevanagari-ExtraBold.ttf: Noto Serif Devanagari,Noto Serif Devanagari ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-SemiBold.ttf: Noto Sans Devanagari,Noto Sans Devanagari SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSerifHebrew-ExtraCondensedExtraLight.ttf: Noto Serif Hebrew,Noto Serif Hebrew ExtraCondensed ExtraLight:style=ExtraCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifSinhala-SemiCondensedBlack.ttf: Noto Serif Sinhala SemiCondensed,Noto Serif Sinhala SemiCondensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansLao-CondensedLight.ttf: Noto Sans Lao Condensed,Noto Sans Lao Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansSoraSompeng-Medium.ttf: Noto Sans Sora Sompeng,Noto Sans Sora Sompeng Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-ExtraCondensedMedium.ttf: Noto Sans Armenian,Noto Sans Armenian ExtraCondensed Medium:style=ExtraCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansTeluguUI-SemiCondensedMedium.ttf: Noto Sans Telugu UI,Noto Sans Telugu UI SemiCondensed Medium:style=SemiCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-ExtraCondensedExtraBold.ttf: Noto Sans Armenian,Noto Sans Armenian ExtraCondensed ExtraBold:style=ExtraCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalamUI-Regular.ttf: Noto Sans Malayalam UI:style=Regular
# /usr/share/fonts/truetype/custom/NotoSans-CondensedExtraLight.ttf: Noto Sans,Noto Sans Condensed ExtraLight:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansCherokee-ExtraLight.ttf: Noto Sans Cherokee,Noto Sans Cherokee ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhala-Condensed.ttf: Noto Sans Sinhala Condensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhalaUI-Condensed.ttf: Noto Sans Sinhala UI Condensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifKhmer-ExtraLight.ttf: Noto Serif Khmer,Noto Serif Khmer ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifMalayalam-Light.ttf: Noto Serif Malayalam,Noto Serif Malayalam Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifTamil-Thin.ttf: Noto Serif Tamil,Noto Serif Tamil Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerifGeorgian-Light.ttf: Noto Serif Georgian,Noto Serif Georgian Lt:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-SemiCondensedExtraLight.ttf: Noto Sans Gujarati,Noto Sans Gujarati SemiCondensed ExtraLight:style=SemiCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifThai-ExtraCondensed.ttf: Noto Serif Thai,Noto Serif Thai ExtraCondensed:style=ExtraCondensed,Regular
# /usr/share/fonts/truetype/custom/NotoSansGujarati-CondensedExtraLight.ttf: Noto Sans Gujarati,Noto Sans Gujarati Condensed ExtraLight:style=Condensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoNaskhArabic-Bold.ttf: Noto Naskh Arabic:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-ExtraLightItalic.ttf: Noto Serif Display,Noto Serif Display ExtraLight:style=ExtraLight Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifDisplay-SemiCondensedExtraLight.ttf: Noto Serif Display SemiCondensed,Noto Serif Display SemiCondensed ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansBalinese-SemiBold.ttf: Noto Sans Balinese,Noto Sans Balinese SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-SemiCondensedExtraLight.ttf: Noto Sans Armenian,Noto Sans Armenian SemiCondensed ExtraLight:style=SemiCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-Medium.ttf: Noto Serif,Noto Serif Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansDevanagari-SemiCondensedExtraBold.ttf: Noto Sans Devanagari,Noto Sans Devanagari SemiCondensed ExtraBold:style=SemiCondensed ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansHanifiRohingya-Medium.ttf: Noto Sans Hanifi Rohingya,Noto Sans Hanifi Rohingya Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoS
ed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansPahawhHmong-Regular.ttf: Noto Sans Pahawh Hmong:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifTamil-SemiCondensedBlackItalic.ttf: Noto Serif Tamil SemiCondensed,Noto Serif Tamil SemiCondensed Black:style=Black Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSerifTelugu-Light.ttf: Noto Serif Telugu,Noto Serif Telugu Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerifTamil-ExtraCondensedItalic.ttf: Noto Serif Tamil ExtraCondensed:style=Italic
# /usr/share/fonts/truetype/custom/NotoSansHebrew-Thin.ttf: Noto Sans Hebrew,Noto Sans Hebrew Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-ExtraCondensedSemiBoldItalic.ttf: Noto Serif,Noto Serif ExtraCondensed SemiBold:style=ExtraCondensed SemiBold Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansKhmer-SemiCondensedBold.ttf: Noto Sans Khmer,Noto Sans Khmer SemiCondensed:style=SemiCondensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSerifMyanmar-ExtraCondensedSemiBold.ttf: Noto Serif Myanmar ExtraCondensed,Noto Serif Myanmar ExtraCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhala-Bold.ttf: Noto Sans Sinhala:style=Bold
# /usr/share/fonts/truetype/custom/NotoSansGurmukhiUI-ExtraCondensedSemiBold.ttf: Noto Sans Gurmukhi UI ExtraCondensed,Noto Sans Gurmukhi UI ExtraCondensed SemiBold:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-SemiBold.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI SmBd:style=SemiBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansTelugu-ExtraLight.ttf: Noto Sans Telugu,Noto Sans Telugu ExtraLight:style=ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSansArmenian-SemiCondensedLight.ttf: Noto Sans Armenian,Noto Sans Armenian SemiCondensed Light:style=SemiCondensed Light,Regular
# /usr/share/fonts/truetype/custom/NotoSansKhmer-CondensedBold.ttf: Noto Sans Khmer,Noto Sans Khmer Condensed:style=Condensed Bold,Bold
# /usr/share/fonts/truetype/custom/NotoSansKannadaUI-CondensedBlack.ttf: Noto Sans Kannada UI,Noto Sans Kannada UI Condensed Black:style=Condensed Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansTamil-ExtraCondensedBold.ttf: Noto Sans Tamil ExtraCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSansMyanmar-SemiCondensedExtraBold.ttf: Noto Sans Myanmar SemiCondensed,Noto Sans Myanmar SemiCondensed ExtraBold:style=ExtraBold,Regular
# /usr/share/fonts/truetype/custom/NotoSansHebrew-ExtraCondensedExtraLight.ttf: Noto Sans Hebrew,Noto Sans Hebrew ExtraCondensed ExtraLight:style=ExtraCondensed ExtraLight,Regular
# /usr/share/fonts/truetype/custom/NotoSerifGujarati-Medium.ttf: Noto Serif Gujarati,Noto Serif Gujarati Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoRashiHebrew-Black.ttf: Noto Rashi Hebrew,Noto Rashi Hebrew Blk:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansArabicUI-Medium.ttf: Noto Sans Arabic UI,Noto Sans Arabic UI Md:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSans-SemiCondensedItalic.ttf: Noto Sans,Noto Sans SemiCondensed:style=SemiCondensed Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansHebrew-SemiCondensedMedium.ttf: Noto Sans Hebrew,Noto Sans Hebrew SemiCondensed Medium:style=SemiCondensed Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-SemiCondensedMedium.ttf: Noto Serif Ethiopic SemiCondensed,Noto Serif Ethiopic SemiCondensed Medium:style=Medium,Regular
# /usr/share/fonts/truetype/custom/NotoSansSinhalaUI-CondensedBlack.ttf: Noto Sans Sinhala UI Condensed,Noto Sans Sinhala UI Condensed Black:style=Black,Regular
# /usr/share/fonts/truetype/custom/NotoSansNabataean-Regular.ttf: Noto Sans Nabataean:style=Regular
# /usr/share/fonts/truetype/custom/NotoSerifEthiopic-Bold.ttf: Noto Serif Ethiopic:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifMyanmar-SemiCondensedBold.ttf: Noto Serif Myanmar SemiCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifTelugu-Thin.ttf: Noto Serif Telugu,Noto Serif Telugu Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSerifBengali-CondensedLight.ttf: Noto Serif Bengali Condensed,Noto Serif Bengali Condensed Light:style=Light,Regular
# /usr/share/fonts/truetype/custom/NotoSerif-ExtraLightItalic.ttf: Noto Serif,Noto Serif ExtraLight:style=ExtraLight Italic,Italic
# /usr/share/fonts/truetype/custom/NotoSansMalayalam-ExtraCondensed.ttf: Noto Sans Malayalam ExtraCondensed:style=Regular
# /usr/share/fonts/truetype/custom/NotoSansMalayalamUI-SemiCondensedBold.ttf: Noto Sans Malayalam UI SemiCondensed:style=Bold
# /usr/share/fonts/truetype/custom/NotoSerifTamil-CondensedThin.ttf: Noto Serif Tamil Condensed,Noto Serif Tamil Condensed Thin:style=Thin,Regular
# /usr/share/fonts/truetype/custom/NotoSans-ExtraCondensedExtraBold.ttf: Noto Sans,Noto Sans ExtraCondensed ExtraBold:style=ExtraCondensed ExtraBold,Regular

# %%
import subprocess

# Run fc-list and decode the output
output = subprocess.check_output(['fc-list'], encoding='utf-8')

# Split the output into lines (each line = one font)
font_list = output.strip().split('\n')
fc_font_names={}

for font in font_list:
  font_name = font.split(':')[1].strip().split(',')[0]
  font_name_striped = ''.join(font_name.split())
  if font_name_striped not in fc_font_names:
    fc_font_names[font_name_striped]=font_name

fc_font_names
# Out:
# {'NotoSansCanadianAboriginal': 'Noto Sans Canadian Aboriginal',
#  'NotoSansKannadaUI': 'Noto Sans Kannada UI',
#  'NotoSansGurmukhiExtraCondensed': 'Noto Sans Gurmukhi ExtraCondensed',
#  'NotoSerif': 'Noto Serif',
#  'NotoSerifThai': 'Noto Serif Thai',
#  'NotoSansKannada': 'Noto Sans Kannada',
#  'NotoSerifEthiopic': 'Noto Serif Ethiopic',
#  'NotoSansDevanagariUI': 'Noto Sans Devanagari UI',
#  'NotoSansBalinese': 'Noto Sans Balinese',
#  'NotoSansSogdian': 'Noto Sans Sogdian',
#  'NotoSansTeluguUI': 'Noto Sans Telugu UI',
#  'NotoSans': 'Noto Sans',
#  'NotoSansTifinaghAzawagh': 'Noto Sans Tifinagh Azawagh',
#  'NotoSansMalayalamSemiCondensed': 'Noto Sans Malayalam SemiCondensed',
#  'NotoSansTamilCondensed': 'Noto Sans Tamil Condensed',
#  'NotoSerifDisplayCondensed': 'Noto Serif Display Condensed',
#  'NotoSerifSinhalaExtraCondensed': 'Noto Serif Sinhala ExtraCondensed',
#  'NotoSansHebrew': 'Noto Sans Hebrew',
#  'NotoSansArabicUI': 'Noto Sans Arabic UI',
#  'NotoSansThaiLooped': 'Noto Sans Thai Looped',
#  'NotoSansMono': 'Noto Sans Mono',
#  'NotoSansCham': 'Noto Sans Cham',
#  'NotoSansThai': 'Noto Sans Thai',
#  'NotoSansGujarati': 'Noto Sans Gujarati',
#  'NotoSansArmenian': 'Noto Sans Armenian',
#  'NotoSansLaoLoopedCondensed': 'Noto Sans Lao Looped Condensed',
#  'NotoSerifKhmer': 'Noto Serif Khmer',
#  'NotoSansGurmukhiUI': 'Noto Sans Gurmukhi UI',
#  'NotoSansGujaratiUI': 'Noto Sans Gujarati UI',
#  'NotoSerifTibetan': 'Noto Serif Tibetan',
#  'NotoSansKhmer': 'Noto Sans Khmer',
#  'NotoSansTamilUICondensed': 'Noto Sans Tamil UI Condensed',
#  'NotoSerifMyanmarSemiCondensed': 'Noto Serif Myanmar SemiCondensed',
#  'NotoSansMyanmar': 'Noto Sans Myanmar',
#  'NotoSerifDevanagari': 'Noto Serif Devanagari',
#  'NotoSansGunjalaGondi': 'Noto Sans Gunjala Gondi',
#  'NotoSansMalayalamUISemiCondensed': 'Noto Sans Malayalam UI SemiCondensed',
#  'NotoSerifArmenian': 'Noto Serif Armenian',
#  'NotoSansTelugu': 'Noto Sans Telugu',
#  'NotoSansTamilUISemiCondensed': 'Noto Sans Tamil UI SemiCondensed',
#  'NotoSerifHebrew': 'Noto Serif Hebrew',
#  'NotoSansArabic': 'Noto Sans Arabic',
#  'NotoSansEthiopic': 'Noto Sans Ethiopic',
#  'NotoSerifEthiopicSemiCondensed': 'Noto Serif Ethiopic SemiCondensed',
#  'NotoSerifMalayalam': 'Noto Serif Malayalam',
#  'NotoSansGurmukhiUICondensed': 'Noto Sans Gurmukhi UI Condensed',
#  'NotoSansTamil': 'Noto Sans Tamil',
#  'NotoSerifBengaliSemiCondensed': 'Noto Serif Bengali SemiCondensed',
#  'NotoSerifDisplaySemiCondensed': 'Noto Serif Display SemiCondensed',
#  'NotoSansGeorgian': 'Noto Sans Georgian',
#  'NotoSansMyanmarExtraCondensed': 'Noto Sans Myanmar ExtraCondensed',
#  'NotoSansSinhalaUI': 'Noto Sans Sinhala UI',
#  'NotoSansMalayalamCondensed': 'Noto Sans Malayalam Condensed',
#  'NotoSerifMyanmar': 'Noto Serif Myanmar',
#  'NotoSansSinhalaUIExtraCondensed': 'Noto Sans Sinhala UI ExtraCondensed',
#  'NotoSansRunic': 'Noto Sans Runic',
#  'NotoSansEthiopicExtraCondensed': 'Noto Sans Ethiopic ExtraCondensed',
#  'NotoSansDevanagari': 'Noto Sans Devanagari',
#  'NotoSansDevanagariUISemiCondensed': 'Noto Sans Devanagari UI SemiCondensed',
#  'NotoRashiHebrew': 'Noto Rashi Hebrew',
#  'NotoSerifGeorgian': 'Noto Serif Georgian',
#  'NotoNaskhArabicUI': 'Noto Naskh Arabic UI',
#  'NotoSansGurmukhiUIExtraCondensed': 'Noto Sans Gurmukhi UI ExtraCondensed',
#  'NotoKufiArabic': 'Noto Kufi Arabic',
#  'NotoSansLao': 'Noto Sans Lao',
#  'NotoSansUgaritic': 'Noto Sans Ugaritic',
#  'NotoSerifToto': 'Noto Serif Toto',
#  'NotoSerifSinhalaCondensed': 'Noto Serif Sinhala Condensed',
#  'NotoSansAdlam': 'Noto Sans Adlam',
#  'NotoSansThaiLoopedSemiCondensed': 'Noto Sans Thai Looped SemiCondensed',
#  'NotoSansZanabazarSquare': 'Noto Sans Zanabazar Square',
#  'NotoSansBhaiksuki': 'Noto Sans Bhaiksuki',
#  'NotoSansVithkuqi': 'Noto Sans Vithkuqi',
#  'NotoSansLaoLoopedSemiCondensed': 'Noto Sans Lao Looped SemiCondensed',
#  'LiberationSansNarrow': 'Liberation Sans Narrow',
#  'NotoSansBengaliUI': 'Noto Sans Bengali UI',
#  'NotoSansTamilUI': 'Noto Sans Tamil UI',
#  'NotoSerifDisplay': 'Noto Serif Display',
#  'NotoSansElymaic': 'Noto Sans Elymaic',
#  'NotoSansEthiopicSemiCondensed': 'Noto Sans Ethiopic SemiCondensed',
#  'NotoSansSundanese': 'Noto Sans Sundanese',
#  'NotoSansGurmukhi': 'Noto Sans Gurmukhi',
#  'NotoSansSyriacWestern': 'Noto Sans Syriac Western',
#  'NotoSansLisu': 'Noto Sans Lisu',
#  'NotoSerifMyanmarCondensed': 'Noto Serif Myanmar Condensed',
#  'NotoSerifEthiopicCondensed': 'Noto Serif Ethiopic Condensed',
#  'NotoSerifDisplayExtraCondensed': 'Noto Serif Display ExtraCondensed',
#  'NotoSansKawi': 'Noto Sans Kawi',
#  'NotoSansSignWriting': 'Noto Sans SignWriting',
#  'NotoSansTamilExtraCondensed': 'Noto Sans Tamil ExtraCondensed',
#  'NotoSansHanifiRohingya': 'Noto Sans Hanifi Rohingya',
#  'NotoSansMedefaidrin': 'Noto Sans Medefaidrin',
#  'NotoSerifBengali': 'Noto Serif Bengali',
#  'NotoSansTamilSemiCondensed': 'Noto Sans Tamil SemiCondensed',
#  'NotoSerifBengaliCondensed': 'Noto Serif Bengali Condensed',
#  'NotoSansMyanmarCondensed': 'Noto Sans Myanmar Condensed',
#  'NotoSerifLaoExtraCondensed': 'Noto Serif Lao ExtraCondensed',
#  'NotoSerifLaoSemiCondensed': 'Noto Serif Lao SemiCondensed',
#  'NotoSansSinhalaSemiCondensed': 'Noto Sans Sinhala SemiCondensed',
#  'NotoSerifLaoCondensed': 'Noto Serif Lao Condensed',
#  'NotoSansSinhalaExtraCondensed': 'Noto Sans Sinhala ExtraCondensed',
#  'NotoSerifOriya': 'Noto Serif Oriya',
#  'NotoSerifEthiopicExtraCondensed': 'Noto Serif Ethiopic ExtraCondensed',
#  'NotoSerifTamilExtraCondensed': 'Noto Serif Tamil ExtraCondensed',
#  'NotoSerifGrantha': 'Noto Serif Grantha',
#  'NotoSerifGurmukhi': 'Noto Serif Gurmukhi',
#  'NotoSansOriya': 'Noto Sans Oriya',
#  'NotoSansSymbols': 'Noto Sans Symbols',
#  'NotoSansBamum': 'Noto Sans Bamum',
#  'LiberationSans': 'Liberation Sans',
#  'NotoSansJavanese': 'Noto Sans Javanese',
#  'NotoSansKhojki': 'Noto Sans Khojki',
#  'NotoSansLaoLooped': 'Noto Sans Lao Looped',
#  'NotoSansTamilUIExtraCondensed': 'Noto Sans Tamil UI ExtraCondensed',
#  'NotoSansCoptic': 'Noto Sans Coptic',
#  'NotoSerifTamil': 'Noto Serif Tamil',
#  'LiberationMono': 'Liberation Mono',
#  'NotoSansDeseret': 'Noto Sans Deseret',
#  'NotoSansBengaliUISemiCondensed': 'Noto Sans Bengali UI SemiCondensed',
#  'NotoSansElbasan': 'Noto Sans Elbasan',
#  'NotoSerifSinhala': 'Noto Serif Sinhala',
#  'NotoSansThaiLoopedExtraCondensed': 'Noto Sans Thai Looped ExtraCondensed',
#  'NotoSansLaoSemiCondensed': 'Noto Sans Lao SemiCondensed',
#  'NotoSansLaoExtraCondensed': 'Noto Sans Lao ExtraCondensed',
#  'NotoSansSinhalaUICondensed': 'Noto Sans Sinhala UI Condensed',
#  'LiberationSerif': 'Liberation Serif',
#  'NotoSansLaoCondensed': 'Noto Sans Lao Condensed',
#  'NotoSerifLao': 'Noto Serif Lao',
#  'NotoSansMalayalamUICondensed': 'Noto Sans Malayalam UI Condensed',
#  'NotoSerifTamilCondensed': 'Noto Serif Tamil Condensed',
#  'NotoSansAdlamUnjoined': 'Noto Sans Adlam Unjoined',
#  'NotoSansSiddham': 'Noto Sans Siddham',
#  'NotoSerifTamilSemiCondensed': 'Noto Serif Tamil SemiCondensed',
#  'NotoSansBengaliUICondensed': 'Noto Sans Bengali UI Condensed',
#  'NotoSansPauCinHau': 'Noto Sans Pau Cin Hau',
#  'NotoSerifTelugu': 'Noto Serif Telugu',
#  'NotoSansEthiopicCondensed': 'Noto Sans Ethiopic Condensed',
#  'NotoSansMendeKikakui': 'Noto Sans Mende Kikakui',
#  'NotoSansSinhalaUISemiCondensed': 'Noto Sans Sinhala UI SemiCondensed',
#  'NotoSansBengali': 'Noto Sans Bengali',
#  'NotoNaskhArabic': 'Noto Naskh Arabic',
#  'NotoNastaliqUrdu': 'Noto Nastaliq Urdu',
#  'NotoSansMeeteiMayek': 'Noto Sans Meetei Mayek',
#  'NotoSerifBengaliExtraCondensed': 'Noto Serif Bengali ExtraCondensed',
#  'NotoSerifTest': 'Noto Serif Test',
#  'NotoSansOsmanya': 'Noto Sans Osmanya',
#  'NotoSansCherokee': 'Noto Sans Cherokee',
#  'NotoSerifVithkuqi': 'Noto Serif Vithkuqi',
#  'NotoSansMahajani': 'Noto Sans Mahajani',
#  'NotoSansSinhalaCondensed': 'Noto Sans Sinhala Condensed',
#  'NotoSansLydian': 'Noto Sans Lydian',
#  'NotoSansOlChiki': 'Noto Sans Ol Chiki',
#  'NotoSansThaiLoopedCondensed': 'Noto Sans Thai Looped Condensed',
#  'NotoSansGurmukhiSemiCondensed': 'Noto Sans Gurmukhi SemiCondensed',
#  'NotoSansPhoenician': 'Noto Sans Phoenician',
#  'NotoSansCarian': 'Noto Sans Carian',
#  'NotoSansDevanagariUIExtraCondensed': 'Noto Sans Devanagari UI ExtraCondensed',
#  'NotoSansBuhid': 'Noto Sans Buhid',
#  'NotoSansSoraSompengSemi': 'Noto Sans Sora Sompeng Semi',
#  'NotoSansMalayalamUI': 'Noto Sans Malayalam UI',
#  'NotoSansGurmukhiCondensed': 'Noto Sans Gurmukhi Condensed',
#  'NotoSerifKannada': 'Noto Serif Kannada',
#  'NotoSansMalayalam': 'Noto Sans Malayalam',
#  'NotoSansMalayalamUIExtraCondensed': 'Noto Sans Malayalam UI ExtraCondensed',
#  'NotoSerifSinhalaSemiCondensed': 'Noto Serif Sinhala SemiCondensed',
#  'NotoSansMyanmarSemiCondensed': 'Noto Sans Myanmar SemiCondensed',
#  'NotoSansThaana': 'Noto Sans Thaana',
#  'NotoSansWarangCiti': 'Noto Sans Warang Citi',
#  'NotoMusic': 'Noto Music',
#  'NotoSansKaithi': 'Noto Sans Kaithi',
#  'NotoSerifDivesAkuru': 'Noto Serif Dives Akuru',
#  'NotoSansCuneiform': 'Noto Sans Cuneiform',
#  'NotoSansBengaliUIExtraCondensed': 'Noto Sans Bengali UI ExtraCondensed',
#  'NotoFangsongKSSRotated': 'Noto Fangsong KSS Rotated',
#  'NotoSansNewTaiLueSemibold': 'Noto Sans New Tai Lue Semibold',
#  'NotoSansBassaVah': 'Noto Sans Bassa Vah',
#  'NotoSerifOldUyghur': 'Noto Serif Old Uyghur',
#  'NotoSansLaoLoopedExtraCondensed': 'Noto Sans Lao Looped ExtraCondensed',
#  'NotoSerifNPHmong': 'Noto Serif NP Hmong',
#  'NotoSansGurmukhiUISemiCondensed': 'Noto Sans Gurmukhi UI SemiCondensed',
#  'NotoSansManichaean': 'Noto Sans Manichaean',
#  'NotoSansTaiTham': 'Noto Sans Tai Tham',
#  'NotoSansNushu': 'Noto Sans Nushu',
#  'NotoSansSoyombo': 'Noto Sans Soyombo',
#  'NotoSansDevanagariUICondensed': 'Noto Sans Devanagari UI Condensed',
#  'NotoSansBrahmi': 'Noto Sans Brahmi',
#  'NotoSansTifinaghAir': 'Noto Sans Tifinagh Air',
#  'NotoSerifKhojki': 'Noto Serif Khojki',
#  'NotoSerifOttomanSiyaq': 'Noto Serif Ottoman Siyaq',
#  'NotoSansMalayalamExtraCondensed': 'Noto Sans Malayalam ExtraCondensed',
#  'NotoSansKayahLi': 'Noto Sans Kayah Li',
#  'NotoSansOldNorthArabian': 'Noto Sans Old North Arabian',
#  'NotoSerifMyanmarExtraCondensed': 'Noto Serif Myanmar ExtraCondensed',
#  'NotoSansRejang': 'Noto Sans Rejang',
#  'NotoSansOsage': 'Noto Sans Osage',
#  'NotoSansCaucasianAlbanian': 'Noto Sans Caucasian Albanian',
#  'NotoSansSharada': 'Noto Sans Sharada',
#  'NotoSansOldHungarian': 'Noto Sans Old Hungarian',
#  'NotoSansTaiLe': 'Noto Sans Tai Le',
#  'NotoSansInscriptionalParthian': 'Noto Sans Inscriptional Parthian',
#  'NotoSansTagbanwa': 'Noto Sans Tagbanwa',
#  'NotoSansDuployan': 'Noto Sans Duployan',
#  'NotoSansLimbu': 'Noto Sans Limbu',
#  'NotoSerifGujarati': 'Noto Serif Gujarati',
#  'NotoSansTifinaghGhat': 'Noto Sans Tifinagh Ghat',
#  'NotoSansMiao': 'Noto Sans Miao',
#  'NotoSansMarchen': 'Noto Sans Marchen',
#  'NotoSansSinhala': 'Noto Sans Sinhala',
#  'NotoSansNKoUnjoined': 'Noto Sans NKo Unjoined',
#  'NotoSerifAhom': 'Noto Serif Ahom',
#  'NotoSansHanunoo': 'Noto Sans Hanunoo',
#  'NotoSansChakma': 'Noto Sans Chakma',
#  'NotoSansLycian': 'Noto Sans Lycian',
#  'NotoSansOldSouthArabian': 'Noto Sans Old South Arabian',
#  'NotoSansMongolian': 'Noto Sans Mongolian',
#  'NotoSansTangsa': 'Noto Sans Tangsa',
#  'NotoSansTest': 'Noto Sans Test',
#  'NotoSerifBalinese': 'Noto Serif Balinese',
#  'NotoSansTifinaghSIL': 'Noto Sans Tifinagh SIL',
#  'NotoTraditionalNushu': 'Noto Traditional Nushu',
#  'NotoSansOldPersian': 'Noto Sans Old Persian',
#  'NotoSansSaurashtra': 'Noto Sans Saurashtra',
#  'NotoSansMasaramGondi': 'Noto Sans Masaram Gondi',
#  'NotoSansSyriac': 'Noto Sans Syriac',
#  'NotoSansNewTaiLue': 'Noto Sans New Tai Lue',
#  'NotoSansSoraSompeng': 'Noto Sans Sora Sompeng',
#  'NotoSansTifinaghAPT': 'Noto Sans Tifinagh APT',
#  'NotoSansPhagsPa': 'Noto Sans PhagsPa',
#  'NotoSansBengaliExtraCondensed': 'Noto Sans Bengali ExtraCondensed',
#  'NotoSerifYezidi': 'Noto Serif Yezidi',
#  'NotoSansTifinaghRhissaIxa': 'Noto Sans Tifinagh Rhissa Ixa',
#  'NotoSansAnatolianHieroglyphs': 'Noto Sans Anatolian Hieroglyphs',
#  'NotoSansNagMundari': 'Noto Sans Nag Mundari',
#  'NotoSansCypriot': 'Noto Sans Cypriot',
#  'NotoSansTakri': 'Noto Sans Takri',
#  'NotoSansTirhuta': 'Noto Sans Tirhuta',
#  'NotoSansGrantha': 'Noto Sans Grantha',
#  'NotoSansInscriptionalPahlavi': 'Noto Sans Inscriptional Pahlavi',
#  'NotoSansSymbols2': 'Noto Sans Symbols 2',
#  'NotoSansTifinaghHawad': 'Noto Sans Tifinagh Hawad',
#  'NotoSansSyriacEastern': 'Noto Sans Syriac Eastern',
#  'NotoSansGlagolitic': 'Noto Sans Glagolitic',
#  'NotoSansMath': 'Noto Sans Math',
#  'NotoSansTifinagh': 'Noto Sans Tifinagh',
#  'NotoSansOldItalic': 'Noto Sans Old Italic',
#  'NotoSansNandinagari': 'Noto Sans Nandinagari',
#  'NotoSansEgyptianHieroglyphs': 'Noto Sans Egyptian Hieroglyphs',
#  'NotoSerifKhitanSmallScript': 'Noto Serif Khitan Small Script',
#  'NotoSansVai': 'Noto Sans Vai',
#  'NotoSansImperialAramaic': 'Noto Sans Imperial Aramaic',
#  'NotoSerifMakasar': 'Noto Serif Makasar',
#  'NotoSansLepcha': 'Noto Sans Lepcha',
#  'NotoSansYi': 'Noto Sans Yi',
#  'NotoSansWancho': 'Noto Sans Wancho',
#  'NotoSansShavian': 'Noto Sans Shavian',
#  'NotoSansMandaic': 'Noto Sans Mandaic',
#  'NotoSansChorasmian': 'Noto Sans Chorasmian',
#  'NotoSansOldSogdian': 'Noto Sans Old Sogdian',
#  'NotoSansLinearA': 'Noto Sans Linear A',
#  'NotoSerifTangut': 'Noto Serif Tangut',
#  'NotoSansCyproMinoan': 'Noto Sans Cypro Minoan',
#  'NotoSansMayanNumerals': 'Noto Sans Mayan Numerals',
#  'NotoSansLinearB': 'Noto Sans Linear B',
#  'NotoSansTifinaghAdrar': 'Noto Sans Tifinagh Adrar',
#  'NotoSansBengaliSemiCondensed': 'Noto Sans Bengali SemiCondensed',
#  'NotoFangsongKSSVertical': 'Noto Fangsong KSS Vertical',
#  'NotoSansKhudawadi': 'Noto Sans Khudawadi',
#  'NotoSansIndicSiyaqNumbers': 'Noto Sans Indic Siyaq Numbers',
#  'NotoSansTifinaghTawellemmet': 'Noto Sans Tifinagh Tawellemmet',
#  'NotoSansMro': 'Noto Sans Mro',
#  'NotoSansGunjalaGondiSemibold': 'Noto Sans Gunjala Gondi Semibold',
#  'NotoSansNKo': 'Noto Sans NKo',
#  'NotoSansKharoshthi': 'Noto Sans Kharoshthi',
#  'NotoSansSylotiNagri': 'Noto Sans Syloti Nagri',
#  'NotoSansBengaliCondensed': 'Noto Sans Bengali Condensed',
#  'NotoSansBuginese': 'Noto Sans Buginese',
#  'NotoSansOgham': 'Noto Sans Ogham',
#  'NotoSansTaiViet': 'Noto Sans Tai Viet',
#  'NotoSansTamilSupplement': 'Noto Sans Tamil Supplement',
#  'NotoSansModi': 'Noto Sans Modi',
#  'NotoSansNewa': 'Noto Sans Newa',
#  'NotoSansMeroitic': 'Noto Sans Meroitic',
#  'NotoSansGothic': 'Noto Sans Gothic',
#  'NotoSansHatran': 'Noto Sans Hatran',
#  'NotoSerifDogra': 'Noto Serif Dogra',
#  'NotoSansTifinaghAhaggar': 'Noto Sans Tifinagh Ahaggar',
#  'NotoSansSamaritan': 'Noto Sans Samaritan',
#  'NotoSansOldPermic': 'Noto Sans Old Permic',
#  'NotoSansAvestan': 'Noto Sans Avestan',
#  'NotoSansPsalterPahlavi': 'Noto Sans Psalter Pahlavi',
#  'NotoNaskhArabicUISemi': 'Noto Naskh Arabic UI Semi',
#  'NotoSansMultani': 'Noto Sans Multani',
#  'NotoSansPalmyrene': 'Noto Sans Palmyrene',
#  'NotoSansTagalog': 'Noto Sans Tagalog',
#  'NotoZnamennyMusicalNotation': 'Noto Znamenny Musical Notation',
#  'NotoSansTifinaghAgrawImazighen': 'Noto Sans Tifinagh Agraw Imazighen',
#  'NotoSansBatak': 'Noto Sans Batak',
#  'NotoSansOldTurkic': 'Noto Sans Old Turkic',
#  'HumorSans': 'Humor Sans',
#  'NotoSansPahawhHmong': 'Noto Sans Pahawh Hmong',
#  'NotoSansNabataean': 'Noto Sans Nabataean'}

# %% [markdown]
# Now go through all the scripts and create the mapping of the Unicode codepoints the fonts which can render them

# %%
import os
from fontTools.ttLib import TTFont
from pprint import pprint

scripts_dir = '/content/scripts'
scripts = os.listdir(scripts_dir)
scripts.sort()

supported_fonts_mapping={}

def print_coverage_summary(results):
    header = f"{'Block':<45} {'Supported / Total':>17} {'Coverage':>10}"
    sep = "-" * len(header)
    # print(header)
    # print(sep)

    for info in results:
        supported = info['supported_count']
        total = info['total_count']
        coverage = info['coverage_percent']
        # print(f"{info['block']:<45} {supported:>7} / {total:<7} {coverage:9.2f}%")

def save_unsupported_chars_as_report(results, filename="unsupported_chars_report.txt"):
    with open(filename, 'w', encoding='utf-8') as f:
        # Write summary table header
        header = f"{'Block':<45} {'Supported / Total':>17} {'Coverage':>10}"
        sep = "-" * len(header)
        f.write(header + "\n")
        f.write(sep + "\n")

        # Write summary table rows
        for info in results:
            supported = info['supported_count']
            total = info['total_count']
            coverage = info['coverage_percent']
            f.write(f"{info['block']:<45} {supported:>7} / {total:<7} {coverage:9.2f}%\n")

        f.write("\n\nUnsupported characters per block:\n\n")

        # Write unsupported characters block by block
        for info in results:
            if info['unsupported_chars']:
                f.write(f"Block: {info['block']}\n")
                f.write(f"Unsupported characters ({len(info['unsupported_chars'])} total):\n")
                for cp in info['unsupported_chars']:
                    f.write(f"U+{cp:04X} ({cp})\n")
                f.write("\n" + "-"*40 + "\n\n")

def analyze_font_coverage(font_path):
    font = TTFont(font_path)
    cmap_table=font['cmap']

    cmap = None

    for table in cmap_table.tables:
      if cmap is None:
        cmap = table.cmap
      else:
        if len(table.cmap) > len(cmap):
          cmap = table.cmap

    if not cmap:
        raise ValueError("No Unicode cmap found in font")

    results = []

    for script in scripts:
        supported_chars = []
        unsupported_chars = []
        script_name = script.split('.')[0]
        total_chars = 0

        with open(os.path.join(scripts_dir, script), 'r', encoding='utf-8') as infile:
            for line in infile:
                line = line.strip()
                if not line.strip():
                    continue
                total_chars += 1
                codepoint = int(line.split('+')[1], 16)
                font_path = os.path.basename(font_path).split('.ttf')[0]
                font_name=""
                if '-' in font_path:
                  font_name = font_path.split('-')[0]
                elif '[' in font_path:
                  font_name = font_path.split('[')[0]

                font_name = fc_font_names[font_name]

                if codepoint in cmap:
                    if line not in supported_fonts_mapping:
                      supported_fonts_mapping[line]=set()
                    supported_fonts_mapping[line].add(font_name)
                    supported_chars.append(codepoint)
                else:
                    unsupported_chars.append(codepoint)

        coverage_percent = (len(supported_chars) / total_chars) * 100 if total_chars else 0.0

        # if round(coverage_percent,2)==100.0:
        #   if script_name not in supported_fonts_mapping:
        #     supported_fonts_mapping[script_name]=[font_path]
        #   else:
        #     supported_fonts_mapping[script_name].append(font_path)

        results.append({
            'block': script_name,
            'supported_count': len(supported_chars),
            'total_count': total_chars,
            'coverage_percent': round(coverage_percent, 2),
            'unsupported_chars': unsupported_chars
        })

    return results

for font_path in pruned_fonts:
  if os.path.exists(font_path):
    try:
      coverage_info = analyze_font_coverage(font_path)
      # print_coverage_summary(coverage_info)
      report_name = f"{os.path.basename(font_path).split('.')[0]}_report.txt"
      # save_unsupported_chars_as_report(coverage_info, report_name)
      print(f"Report saved to {report_name}")

    except Exception as e:
      print(f"Skipped {font_path} due to error: {e}")
  else:
      print("Font file not found.")

for cp in supported_fonts_mapping:
    supported_fonts_mapping[cp] = list(supported_fonts_mapping[cp])
# Out:
# Report saved to NotoFangsongKSSRotated-Regular_report.txt
# Report saved to NotoFangsongKSSVertical-Regular_report.txt
# Report saved to NotoKufiArabic-Regular_report.txt
# Report saved to NotoKufiArabic[wght]_report.txt
# Report saved to NotoMusic-Regular_report.txt
# Report saved to NotoNaskhArabic-Regular_report.txt
# Report saved to NotoNaskhArabic[wght]_report.txt
# Report saved to NotoNaskhArabicUI-Regular_report.txt
# Report saved to NotoNaskhArabicUI[wght]_report.txt
# Report saved to NotoNastaliqUrdu-Regular_report.txt
# Report saved to NotoNastaliqUrdu[wght]_report.txt
# Report saved to NotoRashiHebrew[wght]_report.txt
# Report saved to NotoRashiHebrew-Regular_report.txt
# Report saved to NotoSans-Regular_report.txt
# Report saved to NotoSans[wdth,wght]_report.txt
# Report saved to NotoSans[wght]_report.txt
# Report saved to NotoSansAdlam-Regular_report.txt
# Report saved to NotoSansAdlam[wght]_report.txt
# Report saved to NotoSansAdlamUnjoined-Regular_report.txt
# Report saved to NotoSansAdlamUnjoined[wght]_report.txt
# Report saved to NotoSansAnatolianHieroglyphs-Regular_report.txt
# Report saved to NotoSansArabic-Regular_report.txt
# Report saved to NotoSansArabic[wdth,wght]_report.txt
# Report saved to NotoSansArabic[wght]_report.txt
# Report saved to NotoSansArabicUI[wdth,wght]_report.txt
# Report saved to NotoSansArabicUI[wght]_report.txt
# Report saved to NotoSansArabicUI-Regular_report.txt
# Report saved to NotoSansArmenian-Regular_report.txt
# Report saved to NotoSansArmenian[wdth,wght]_report.txt
# Report saved to NotoSansArmenian[wght]_report.txt
# Report saved to NotoSansAvestan-Regular_report.txt
# Report saved to NotoSansBalinese-Regular_report.txt
# Report saved to NotoSansBalinese[wght]_report.txt
# Report saved to NotoSansBamum-Regular_report.txt
# Report saved to NotoSansBamum[wght]_report.txt
# Report saved to NotoSansBassaVah-Regular_report.txt
# Report saved to NotoSansBassaVah[wght]_report.txt
# Report saved to NotoSansBatak-Regular_report.txt
# Report saved to NotoSansBengali-Regular_report.txt
# Report saved to NotoSansBengaliUI-Regular_report.txt
# Report saved to NotoSansBengali[wdth,wght]_report.txt
# Report saved to NotoSansBengali[wght]_report.txt
# Report saved to NotoSansBhaiksuki-Regular_report.txt
# Report saved to NotoSansBrahmi-Regular_report.txt
# Report saved to NotoSansBuginese-Regular_report.txt
# Report saved to NotoSansBuhid-Regular_report.txt
# Report saved to NotoSansCanadianAboriginal-Regular_report.txt
# Report saved to NotoSansCanadianAboriginal[wght]_report.txt
# Report saved to NotoSansCarian-Regular_report.txt
# Report saved to NotoSansCaucasianAlbanian-Regular_report.txt
# Report saved to NotoSansChakma-Regular_report.txt
# Report saved to NotoSansCham-Regular_report.txt
# Report saved to NotoSansCham[wght]_report.txt
# Report saved to NotoSansCherokee-Regular_report.txt
# Report saved to NotoSansCherokee[wght]_report.txt
# Report saved to NotoSansChorasmian-Regular_report.txt
# Report saved to NotoSansCoptic-Regular_report.txt
# Report saved to NotoSansCuneiform-Regular_report.txt
# Report saved to NotoSansCypriot-Regular_report.txt
# Report saved to NotoSansCyproMinoan-Regular_report.txt
# Report saved to NotoSansDeseret-Regular_report.txt
# Report saved to NotoSansDevanagari-Regular_report.txt
# Report saved to NotoSansDevanagariUI-Regular_report.txt
# Report saved to NotoSansDevanagari[wdth,wght]_report.txt
# Report saved to NotoSansDevanagari[wght]_report.txt
# Report saved to NotoSansDuployan-Regular_report.txt
# Report saved to NotoSansEgyptianHieroglyphs-Regular_report.txt
# Report saved to NotoSansElbasan-Regular_report.txt
# Report saved to NotoSansElymaic-Regular_report.txt
# Report saved to NotoSansEthiopic-Regular_report.txt
# Report saved to NotoSansEthiopic[wdth,wght]_report.txt
# Report saved to NotoSansEthiopic[wght]_report.txt
# Report saved to NotoSansGeorgian-Regular_report.txt
# Report saved to NotoSansGeorgian[wdth,wght]_report.txt
# Report saved to NotoSansGeorgian[wght]_report.txt
# Report saved to NotoSansGlagolitic-Regular_report.txt
# Report saved to NotoSansGothic-Regular_report.txt
# Report saved to NotoSansGrantha-Regular_report.txt
# Report saved to NotoSansGujarati-Regular_report.txt
# Report saved to NotoSansGujaratiUI-Regular_report.txt
# Report saved to NotoSansGujarati[wdth,wght]_report.txt
# Report saved to NotoSansGujarati[wght]_report.txt
# Report saved to NotoSansGunjalaGondi-Regular_report.txt
# Report saved to NotoSansGunjalaGondi[wght]_report.txt
# Report saved to NotoSansGurmukhi-Regular_report.txt
# Report saved to NotoSansGurmukhiUI-Regular_report.txt
# Report saved to NotoSansGurmukhi[wdth,wght]_report.txt
# Report saved to NotoSansGurmukhi[wght]_report.txt
# Report saved to NotoSansHanifiRohingya-Regular_report.txt
# Report saved to NotoSansHanifiRohingya[wght]_report.txt
# Report saved to NotoSansHanunoo-Regular_report.txt
# Report saved to NotoSansHatran-Regular_report.txt
# Report saved to NotoSansHebrew-Regular_report.txt
# Report saved to NotoSansHebrew[wdth,wght]_report.txt
# Report saved to NotoSansHebrew[wght]_report.txt
# Report saved to NotoSansImperialAramaic-Regular_report.txt
# Report saved to NotoSansIndicSiyaqNumbers-Regular_report.txt
# Report saved to NotoSansInscriptionalPahlavi-Regular_report.txt
# Report saved to NotoSansInscriptionalParthian-Regular_report.txt
# Report saved to NotoSansJavanese-Regular_report.txt
# Report saved to NotoSansJavanese[wght]_report.txt
# Report saved to NotoSansKaithi-Regular_report.txt
# Report saved to NotoSansKannada-Regular_report.txt
# Report saved to NotoSansKannadaUI-Regular_report.txt
# Report saved to NotoSansKannada[wdth,wght]_report.txt
# Report saved to NotoSansKannada[wght]_report.txt
# Report saved to NotoSansKawi-Regular_report.txt
# Report saved to NotoSansKawi[wght]_report.txt
# Report saved to NotoSansKayahLi-Regular_report.txt
# Report saved to NotoSansKayahLi[wght]_report.txt
# Report saved to NotoSansKharoshthi-Regular_report.txt
# Report saved to NotoSansKhmer-Regular_report.txt
# Report saved to NotoSansKhmer[wdth,wght]_report.txt
# Report saved to NotoSansKhmer[wght]_report.txt
# Report saved to NotoSansKhojki-Regular_report.txt
# Report saved to NotoSansKhudawadi-Regular_report.txt
# Report saved to NotoSansLao-Regular_report.txt
# Report saved to NotoSansLao[wdth,wght]_report.txt
# Report saved to NotoSansLao[wght]_report.txt
# Report saved to NotoSansLaoLooped-Regular_report.txt
# Report saved to NotoSansLaoLooped[wdth,wght]_report.txt
# Report saved to NotoSansLaoLooped[wght]_report.txt
# Report saved to NotoSansLepcha-Regular_report.txt
# Report saved to NotoSansLimbu-Regular_report.txt
# Report saved to NotoSansLinearA-Regular_report.txt
# Report saved to NotoSansLinearB-Regular_report.txt
# Report saved to NotoSansLisu-Regular_report.txt
# Report saved to NotoSansLisu[wght]_report.txt
# Report saved to NotoSansLycian-Regular_report.txt
# Report saved to NotoSansLydian-Regular_report.txt
# Report saved to NotoSansMahajani-Regular_report.txt
# Report saved to NotoSansMalayalam-Regular_report.txt
# Report saved to NotoSansMalayalamUI-Regular_report.txt
# Report saved to NotoSansMalayalam[wdth,wght]_report.txt
# Report saved to NotoSansMalayalam[wght]_report.txt
# Report saved to NotoSansMandaic-Regular_report.txt
# Report saved to NotoSansManichaean-Regular_report.txt
# Report saved to NotoSansMarchen-Regular_report.txt
# Report saved to NotoSansMasaramGondi-Regular_report.txt
# Report saved to NotoSansMath-Regular_report.txt
# Report saved to NotoSansMayanNumerals-Regular_report.txt
# Report saved to NotoSansMedefaidrin-Regular_report.txt
# Report saved to NotoSansMedefaidrin[wght]_report.txt
# Report saved to NotoSansMeeteiMayek-Regular_report.txt
# Report saved to NotoSansMeeteiMayek[wght]_report.txt
# Report saved to NotoSansMendeKikakui-Regular_report.txt
# Report saved to NotoSansMeroitic-Regular_report.txt
# Report saved to NotoSansMiao-Regular_report.txt
# Report saved to NotoSansModi-Regular_report.txt
# Report saved to NotoSansMongolian-Regular_report.txt
# Report saved to NotoSansMono-Regular_report.txt
# Report saved to NotoSansMono[wdth,wght]_report.txt
# Report saved to NotoSansMono[wght]_report.txt
# Report saved to NotoSansMro-Regular_report.txt
# Report saved to NotoSansMultani-Regular_report.txt
# Report saved to NotoSansMyanmar-Regular_report.txt
# Report saved to NotoSansMyanmar[wdth,wght]_report.txt
# Report saved to NotoSansMyanmar[wght]_report.txt
# Report saved to NotoSansNKo-Regular_report.txt
# Report saved to NotoSansNKoUnjoined-Regular_report.txt
# Report saved to NotoSansNKoUnjoined[wght]_report.txt
# Report saved to NotoSansNabataean-Regular_report.txt
# Report saved to NotoSansNagMundari-Regular_report.txt
# Report saved to NotoSansNagMundari[wght]_report.txt
# Report saved to NotoSansNandinagari-Regular_report.txt
# Report saved to NotoSansNewTaiLue-Regular_report.txt
# Report saved to NotoSansNewTaiLue[wght]_report.txt
# Report saved to NotoSansNewa-Regular_report.txt
# Report saved to NotoSansNushu-Regular_report.txt
# Report saved to NotoSansOgham-Regular_report.txt
# Report saved to NotoSansOlChiki-Regular_report.txt
# Report saved to NotoSansOlChiki[wght]_report.txt
# Report saved to NotoSansOldHungarian-Regular_report.txt
# Report saved to NotoSansOldItalic-Regular_report.txt
# Report saved to NotoSansOldNorthArabian-Regular_report.txt
# Report saved to NotoSansOldPermic-Regular_report.txt
# Report saved to NotoSansOldPersian-Regular_report.txt
# Report saved to NotoSansOldSogdian-Regular_report.txt
# Report saved to NotoSansOldSouthArabian-Regular_report.txt
# Report saved to NotoSansOldTurkic-Regular_report.txt
# Report saved to NotoSansOriya-Regular_report.txt
# Report saved to NotoSansOriya[wdth,wght]_report.txt
# Report saved to NotoSansOriya[wght]_report.txt
# Report saved to NotoSansOsage-Regular_report.txt
# Report saved to NotoSansOsmanya-Regular_report.txt
# Report saved to NotoSansPahawhHmong-Regular_report.txt
# Report saved to NotoSansPalmyrene-Regular_report.txt
# Report saved to NotoSansPauCinHau-Regular_report.txt
# Report saved to NotoSansPhagsPa-Regular_report.txt
# Report saved to NotoSansPhoenician-Regular_report.txt
# Report saved to NotoSansPsalterPahlavi-Regular_report.txt
# Report saved to NotoSansRejang-Regular_report.txt
# Report saved to NotoSansRunic-Regular_report.txt
# Report saved to NotoSansSamaritan-Regular_report.txt
# Report saved to NotoSansSaurashtra-Regular_report.txt
# Report saved to NotoSansSharada-Regular_report.txt
# Report saved to NotoSansShavian-Regular_report.txt
# Report saved to NotoSansSiddham-Regular_report.txt
# Report saved to NotoSansSignWriting-Regular_report.txt
# Report saved to NotoSansSinhala-Regular_report.txt
# Report saved to NotoSansSinhalaUI-Regular_report.txt
# Report saved to NotoSansSinhala[wdth,wght]_report.txt
# Report saved to NotoSansSinhala[wght]_report.txt
# Report saved to NotoSansSogdian-Regular_report.txt
# Report saved to NotoSansSoraSompeng-Regular_report.txt
# Report saved to NotoSansSoraSompeng[wght]_report.txt
# Report saved to NotoSansSoyombo-Regular_report.txt
# Report saved to NotoSansSundanese-Regular_report.txt
# Report saved to NotoSansSundanese[wght]_report.txt
# Report saved to NotoSansSylotiNagri-Regular_report.txt
# Report saved to NotoSansSymbols-Regular_report.txt
# Report saved to NotoSansSymbols[wght]_report.txt
# Report saved to NotoSansSymbols2-Regular_report.txt
# Report saved to NotoSansSyriac-Regular_report.txt
# Report saved to NotoSansSyriac[wght]_report.txt
# Report saved to NotoSansSyriacEastern-Regular_report.txt
# Report saved to NotoSansSyriacEastern[wght]_report.txt
# Report saved to NotoSansSyriacWestern-Regular_report.txt
# Report saved to NotoSansSyriacWestern[wght]_report.txt
# Report saved to NotoSansTagalog-Regular_report.txt
# Report saved to NotoSansTagbanwa-Regular_report.txt
# Report saved to NotoSansTaiLe-Regular_report.txt
# Report saved to NotoSansTaiTham-Regular_report.txt
# Report saved to NotoSansTaiTham[wght]_report.txt
# Report saved to NotoSansTaiViet-Regular_report.txt
# Report saved to NotoSansTakri-Regular_report.txt
# Report saved to NotoSansTamil-Regular_report.txt
# Report saved to NotoSansTamilUI-Regular_report.txt
# Report saved to NotoSansTamil[wdth,wght]_report.txt
# Report saved to NotoSansTamil[wght]_report.txt
# Report saved to NotoSansTamilSupplement-Regular_report.txt
# Report saved to NotoSansTangsa-Regular_report.txt
# Report saved to NotoSansTangsa[wght]_report.txt
# Report saved to NotoSansTelugu-Regular_report.txt
# Report saved to NotoSansTeluguUI-Regular_report.txt
# Report saved to NotoSansTelugu[wdth,wght]_report.txt
# Report saved to NotoSansTelugu[wght]_report.txt
# Report saved to NotoSansTest-Regular_report.txt
# Report saved to NotoSansTest[wght]_report.txt
# Report saved to NotoSansThaana-Regular_report.txt
# Report saved to NotoSansThaana[wght]_report.txt
# Report saved to NotoSansThai-Regular_report.txt
# Report saved to NotoSansThai[wdth,wght]_report.txt
# Report saved to NotoSansThai[wght]_report.txt
# Report saved to NotoSansThaiLooped-Regular_report.txt
# Report saved to NotoSansThaiLooped[wdth,wght]_report.txt
# Report saved to NotoSansThaiLooped[wght]_report.txt
# Report saved to NotoSansTifinagh-Regular_report.txt
# Report saved to NotoSansTifinaghAPT-Regular_report.txt
# Report saved to NotoSansTifinaghAdrar-Regular_report.txt
# Report saved to NotoSansTifinaghAgrawImazighen-Regular_report.txt
# Report saved to NotoSansTifinaghAhaggar-Regular_report.txt
# Report saved to NotoSansTifinaghAir-Regular_report.txt
# Report saved to NotoSansTifinaghAzawagh-Regular_report.txt
# Report saved to NotoSansTifinaghGhat-Regular_report.txt
# Report saved to NotoSansTifinaghHawad-Regular_report.txt
# Report saved to NotoSansTifinaghRhissaIxa-Regular_report.txt
# Report saved to NotoSansTifinaghSIL-Regular_report.txt
# Report saved to NotoSansTifinaghTawellemmet-Regular_report.txt
# Report saved to NotoSansTirhuta-Regular_report.txt
# Report saved to NotoSansUgaritic-Regular_report.txt
# Report saved to NotoSansVai-Regular_report.txt
# Report saved to NotoSansVithkuqi-Regular_report.txt
# Report saved to NotoSansVithkuqi[wght]_report.txt
# Report saved to NotoSansWancho-Regular_report.txt
# Report saved to NotoSansWarangCiti-Regular_report.txt
# Report saved to NotoSansYi-Regular_report.txt
# Report saved to NotoSansZanabazarSquare-Regular_report.txt
# Report saved to NotoSerif-Regular_report.txt
# Report saved to NotoSerif[wdth,wght]_report.txt
# Report saved to NotoSerif[wght]_report.txt
# Report saved to NotoSerifAhom-Regular_report.txt
# Report saved to NotoSerifArmenian-Regular_report.txt
# Report saved to NotoSerifArmenian[wdth,wght]_report.txt
# Report saved to NotoSerifArmenian[wght]_report.txt
# Report saved to NotoSerifBalinese-Regular_report.txt
# Report saved to NotoSerifBengali-Regular_report.txt
# Report saved to NotoSerifBengali[wdth,wght]_report.txt
# Report saved to NotoSerifBengali[wght]_report.txt
# Report saved to NotoSerifDevanagari-Regular_report.txt
# Report saved to NotoSerifDevanagari[wdth,wght]_report.txt
# Report saved to NotoSerifDevanagari[wght]_report.txt
# Report saved to NotoSerifDisplay-Regular_report.txt
# Report saved to NotoSerifDisplay[wdth,wght]_report.txt
# Report saved to NotoSerifDisplay[wght]_report.txt
# Report saved to NotoSerifDivesAkuru-Regular_report.txt
# Report saved to NotoSerifDogra-Regular_report.txt
# Report saved to NotoSerifEthiopic-Regular_report.txt
# Report saved to NotoSerifEthiopic[wdth,wght]_report.txt
# Report saved to NotoSerifEthiopic[wght]_report.txt
# Report saved to NotoSerifGeorgian-Regular_report.txt
# Report saved to NotoSerifGeorgian[wdth,wght]_report.txt
# Report saved to NotoSerifGeorgian[wght]_report.txt
# Report saved to NotoSerifGrantha-Regular_report.txt
# Report saved to NotoSerifGujarati-Regular_report.txt
# Report saved to NotoSerifGujarati[wght]_report.txt
# Report saved to NotoSerifGurmukhi-Regular_report.txt
# Report saved to NotoSerifGurmukhi[wght]_report.txt
# Report saved to NotoSerifHebrew-Regular_report.txt
# Report saved to NotoSerifHebrew[wdth,wght]_report.txt
# Report saved to NotoSerifHebrew[wght]_report.txt
# Report saved to NotoSerifKannada-Regular_report.txt
# Report saved to NotoSerifKannada[wght]_report.txt
# Report saved to NotoSerifKhitanSmallScript-Regular_report.txt
# Report saved to NotoSerifKhmer-Regular_report.txt
# Report saved to NotoSerifKhmer[wdth,wght]_report.txt
# Report saved to NotoSerifKhmer[wght]_report.txt
# Report saved to NotoSerifKhojki-Regular_report.txt
# Report saved to NotoSerifKhojki[wght]_report.txt
# Report saved to NotoSerifLao-Regular_report.txt
# Report saved to NotoSerifLao[wdth,wght]_report.txt
# Report saved to NotoSerifLao[wght]_report.txt
# Report saved to NotoSerifMakasar-Regular_report.txt
# Report saved to NotoSerifMalayalam-Regular_report.txt
# Report saved to NotoSerifMalayalam[wght]_report.txt
# Report saved to NotoSerifMyanmar-Regular_report.txt
# Report saved to NotoSerifMyanmar[wdth,wght]_report.txt
# Report saved to NotoSerifMyanmar[wght]_report.txt
# Report saved to NotoSerifNPHmong-Regular_report.txt
# Report saved to NotoSerifNPHmong[wght]_report.txt
# Report saved to NotoSerifOldUyghur-Regular_report.txt
# Report saved to NotoSerifOriya-Regular_report.txt
# Report saved to NotoSerifOriya[wght]_report.txt
# Report saved to NotoSerifOttomanSiyaq-Regular_report.txt
# Report saved to NotoSerifSinhala-Regular_report.txt
# Report saved to NotoSerifSinhala[wdth,wght]_report.txt
# Report saved to NotoSerifSinhala[wght]_report.txt
# Report saved to NotoSerifTamil-Regular_report.txt
# Report saved to NotoSerifTamil[wdth,wght]_report.txt
# Report saved to NotoSerifTamil[wght]_report.txt
# Report saved to NotoSerifTangut-Regular_report.txt
# Report saved to NotoSerifTelugu-Regular_report.txt
# Report saved to NotoSerifTelugu[wght]_report.txt
# Report saved to NotoSerifTest[wght]_report.txt
# Report saved to NotoSerifTest-Regular_report.txt
# Report saved to NotoSerifThai-Regular_report.txt
# Report saved to NotoSerifThai[wdth,wght]_report.txt
# Report saved to NotoSerifThai[wght]_report.txt
# Report saved to NotoSerifTibetan[wght]_report.txt
# Report saved to NotoSerifTibetan-Regular_report.txt
# Report saved to NotoSerifToto-Regular_report.txt
# Report saved to NotoSerifToto[wght]_report.txt
# Report saved to NotoSerifVithkuqi-Regular_report.txt
# Report saved to NotoSerifVithkuqi[wght]_report.txt
# Report saved to NotoSerifYezidi-Regular_report.txt
# Report saved to NotoSerifYezidi[wght]_report.txt
# Report saved to NotoTraditionalNushu-Regular_report.txt
# Report saved to NotoTraditionalNushu[wght]_report.txt
# Report saved to NotoZnamennyMusicalNotation-Regular_report.txt

# %%
supported_fonts_mapping["U+0021"]
# Out:
# ['Noto Sans Tifinagh SIL',
#  'Noto Sans Mahajani',
#  'Noto Sans Sundanese',
#  'Noto Kufi Arabic',
#  'Noto Sans Soyombo',
#  'Noto Sans Lepcha',
#  'Noto Sans',
#  'Noto Sans Devanagari UI',
#  'Noto Sans Tifinagh APT',
#  'Noto Naskh Arabic',
#  'Noto Fangsong KSS Rotated',
#  'Noto Sans Georgian',
#  'Noto Sans Devanagari',
#  'Noto Sans Palmyrene',
#  'Noto Sans Bamum',
#  'Noto Serif Balinese',
#  'Noto Sans Tifinagh Ghat',
#  'Noto Sans Vithkuqi',
#  'Noto Serif Bengali',
#  'Noto Sans Old Turkic',
#  'Noto Serif Devanagari',
#  'Noto Sans Ugaritic',
#  'Noto Sans Sogdian',
#  'Noto Sans Cham',
#  'Noto Sans Sinhala',
#  'Noto Sans Canadian Aboriginal',
#  'Noto Sans Osmanya',
#  'Noto Serif Khmer',
#  'Noto Serif Tangut',
#  'Noto Naskh Arabic UI',
#  'Noto Sans Linear B',
#  'Noto Sans Imperial Aramaic',
#  'Noto Serif Ahom',
#  'Noto Sans Marchen',
#  'Noto Serif NP Hmong',
#  'Noto Rashi Hebrew',
#  'Noto Sans Mono',
#  'Noto Sans Lydian',
#  'Noto Sans Multani',
#  'Noto Sans Tifinagh Air',
#  'Noto Sans Nag Mundari',
#  'Noto Serif Thai',
#  'Noto Sans Kannada UI',
#  'Noto Sans Lao Looped',
#  'Noto Sans Test',
#  'Noto Sans Gurmukhi UI',
#  'Noto Serif Yezidi',
#  'Noto Sans Javanese',
#  'Noto Sans Chorasmian',
#  'Noto Sans Zanabazar Square',
#  'Noto Serif Khojki',
#  'Noto Serif Telugu',
#  'Noto Sans Buhid',
#  'Noto Sans Modi',
#  'Noto Sans Telugu UI',
#  'Noto Serif Gurmukhi',
#  'Noto Sans Balinese',
#  'Noto Serif Test',
#  'Noto Sans Tifinagh',
#  'Noto Sans Cherokee',
#  'Noto Sans Gujarati',
#  'Noto Sans Coptic',
#  'Noto Sans Bengali UI',
#  'Noto Sans Sharada',
#  'Noto Sans Malayalam UI',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Saurashtra',
#  'Noto Sans Myanmar',
#  'Noto Sans Batak',
#  'Noto Sans Miao',
#  'Noto Sans Old North Arabian',
#  'Noto Sans Syriac Western',
#  'Noto Serif Vithkuqi',
#  'Noto Sans Elymaic',
#  'Noto Sans Tamil UI',
#  'Noto Serif Myanmar',
#  'Noto Sans Lisu',
#  'Noto Sans Chakma',
#  'Noto Sans Tifinagh Adrar',
#  'Noto Serif Malayalam',
#  'Noto Serif Ethiopic',
#  'Noto Sans Lycian',
#  'Noto Sans Mandaic',
#  'Noto Serif Tibetan',
#  'Noto Sans Tai Le',
#  'Noto Sans Yi',
#  'Noto Fangsong KSS Vertical',
#  'Noto Sans Tirhuta',
#  'Noto Sans Bassa Vah',
#  'Noto Sans Siddham',
#  'Noto Sans Deseret',
#  'Noto Sans Lao',
#  'Noto Sans Cuneiform',
#  'Noto Sans Math',
#  'Noto Sans SignWriting',
#  'Noto Sans Tagalog',
#  'Noto Sans Thai',
#  'Noto Sans Mro',
#  'Noto Sans Duployan',
#  'Noto Sans Glagolitic',
#  'Noto Serif Gujarati',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Ethiopic',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Symbols',
#  'Noto Sans Tifinagh Ahaggar',
#  'Noto Serif Kannada',
#  'Noto Sans Tai Viet',
#  'Noto Serif Oriya',
#  'Noto Sans Anatolian Hieroglyphs',
#  'Noto Sans Malayalam',
#  'Noto Serif Toto',
#  'Noto Serif Lao',
#  'Noto Sans Old Sogdian',
#  'Noto Sans Old Permic',
#  'Noto Sans Old South Arabian',
#  'Noto Music',
#  'Noto Sans Tagbanwa',
#  'Noto Serif Grantha',
#  'Noto Sans Inscriptional Parthian',
#  'Noto Sans Masaram Gondi',
#  'Noto Sans Arabic',
#  'Noto Sans Nabataean',
#  'Noto Serif Armenian',
#  'Noto Sans Khojki',
#  'Noto Sans Kannada',
#  'Noto Sans Old Persian',
#  'Noto Sans Meroitic',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans Tifinagh Hawad',
#  'Noto Sans Warang Citi',
#  'Noto Sans Indic Siyaq Numbers',
#  'Noto Sans Tai Tham',
#  'Noto Sans Grantha',
#  'Noto Sans Kaithi',
#  'Noto Sans Adlam',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans Nandinagari',
#  'Noto Sans Thai Looped',
#  'Noto Sans Ol Chiki',
#  'Noto Sans Symbols 2',
#  'Noto Sans Osage',
#  'Noto Sans Rejang',
#  'Noto Sans Cypriot',
#  'Noto Sans Gunjala Gondi',
#  'Noto Sans Meetei Mayek',
#  'Noto Sans Hatran',
#  'Noto Sans Adlam Unjoined',
#  'Noto Sans Hanunoo',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Noto Sans Syriac',
#  'Noto Serif Dogra',
#  'Noto Sans Mende Kikakui',
#  'Noto Traditional Nushu',
#  'Noto Sans Thaana',
#  'Noto Sans Tifinagh Tawellemmet',
#  'Noto Sans Brahmi',
#  'Noto Sans Vai',
#  'Noto Sans Elbasan',
#  'Noto Sans Avestan',
#  'Noto Sans Tamil Supplement',
#  'Noto Sans Ogham',
#  'Noto Serif Ottoman Siyaq',
#  'Noto Serif Hebrew',
#  'Noto Sans Telugu',
#  'Noto Sans Carian',
#  'Noto Sans Kawi',
#  'Noto Sans New Tai Lue',
#  'Noto Sans Shavian',
#  'Noto Sans Syriac Eastern',
#  'Noto Serif Makasar',
#  'Noto Znamenny Musical Notation',
#  'Noto Sans Sinhala UI',
#  'Noto Sans Khudawadi',
#  'Noto Sans Manichaean',
#  'Noto Sans Hebrew',
#  'Noto Serif',
#  'Noto Sans Limbu',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans Wancho',
#  'Noto Serif Display',
#  'Noto Sans Medefaidrin',
#  'Noto Sans NKo Unjoined',
#  'Noto Sans Khmer',
#  'Noto Serif Georgian',
#  'Noto Sans Gurmukhi',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Takri',
#  'Noto Sans Tangsa',
#  'Noto Sans Mayan Numerals',
#  'Noto Sans Bengali',
#  'Noto Sans Linear A',
#  'Noto Sans Mongolian',
#  'Noto Sans Old Italic',
#  'Noto Sans Samaritan',
#  'Noto Sans Tifinagh Azawagh',
#  'Noto Sans Tamil',
#  'Noto Sans Nushu',
#  'Noto Sans Armenian',
#  'Noto Sans Tifinagh Agraw Imazighen',
#  'Noto Sans Gothic',
#  'Noto Sans Phoenician',
#  'Noto Serif Tamil',
#  'Noto Sans Cypro Minoan',
#  'Noto Sans Runic',
#  'Noto Sans Arabic UI',
#  'Noto Sans Oriya',
#  'Noto Sans PhagsPa',
#  'Noto Serif Dives Akuru',
#  'Noto Sans Newa',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Buginese',
#  'Noto Sans NKo',
#  'Noto Serif Sinhala',
#  'Noto Sans Tifinagh Rhissa Ixa',
#  'Noto Nastaliq Urdu',
#  'Noto Sans Kayah Li',
#  'Noto Sans Gujarati UI',
#  'Noto Serif Old Uyghur',
#  'Noto Sans Pahawh Hmong',
#  'Noto Serif Khitan Small Script',
#  'Noto Sans Sora Sompeng']

# %%
import json

# Save to JSON file
json_filename = "supported_fonts_mapping_combined.json"

with open(json_filename, 'w', encoding='utf-8') as json_file:
    json.dump(supported_fonts_mapping, json_file, indent=4, ensure_ascii=False)

print(f"Supported fonts mapping saved to {json_filename}")
# Out:
# Supported fonts mapping saved to supported_fonts_mapping_combined.json

# %% [markdown]
# ## Find the unsupported characters

# %%
unsupported_chars = []

for script in scripts:
    script_name = script.split('.')[0]

    with open(os.path.join(scripts_dir, script), 'r', encoding='utf-8') as infile:
        for line in infile:
            line = line.strip()
            if not line:
                continue  # skip blank lines
            if line not in supported_fonts_mapping:
                unsupported_chars.append(line)

# %%
len(unsupported_chars)
# Out:
# 83

# %%
unsupported_chars
# Out:
# ['U+1AC1',
#  'U+1AC2',
#  'U+1AC3',
#  'U+1AC4',
#  'U+1AC6',
#  'U+1DFA',
#  'U+1C89',
#  'U+1C8A',
#  'U+1E030',
#  'U+1E031',
#  'U+1E032',
#  'U+1E033',
#  'U+1E034',
#  'U+1E035',
#  'U+1E036',
#  'U+1E037',
#  'U+1E038',
#  'U+1E039',
#  'U+1E03A',
#  'U+1E03B',
#  'U+1E03C',
#  'U+1E03D',
#  'U+1E03E',
#  'U+1E03F',
#  'U+1E040',
#  'U+1E041',
#  'U+1E042',
#  'U+1E043',
#  'U+1E044',
#  'U+1E045',
#  'U+1E046',
#  'U+1E047',
#  'U+1E048',
#  'U+1E049',
#  'U+1E04A',
#  'U+1E04B',
#  'U+1E04C',
#  'U+1E04D',
#  'U+1E04E',
#  'U+1E04F',
#  'U+1E050',
#  'U+1E051',
#  'U+1E052',
#  'U+1E053',
#  'U+1E054',
#  'U+1E055',
#  'U+1E056',
#  'U+1E057',
#  'U+1E058',
#  'U+1E059',
#  'U+1E05A',
#  'U+1E05B',
#  'U+1E05C',
#  'U+1E05D',
#  'U+1E05E',
#  'U+1E05F',
#  'U+1E060',
#  'U+1E061',
#  'U+1E062',
#  'U+1E063',
#  'U+1E064',
#  'U+1E065',
#  'U+1E066',
#  'U+1E067',
#  'U+1E068',
#  'U+1E069',
#  'U+1E06A',
#  'U+1E06B',
#  'U+1E06C',
#  'U+1E06D',
#  'U+1E08F',
#  'U+A7CB',
#  'U+A7CC',
#  'U+A7CD',
#  'U+A7DA',
#  'U+A7DB',
#  'U+A7DC',
#  'U+1DF25',
#  'U+1DF26',
#  'U+1DF27',
#  'U+1DF28',
#  'U+1DF29',
#  'U+1DF2A']

# %%
with open("unsupported_chars_noto_combined.txt",'w', encoding='utf-8') as f:
  f.write(", ".join(unsupported_chars))

# %% [markdown]
# ### Install Roboto fonts (if required)

# %%
# !git clone https://github.com/googlefonts/roboto-3-classic.git
# Out:
# Cloning into 'roboto-3-classic'...
# remote: Enumerating objects: 234786, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 234786 (delta 118), reused 121 (delta 91), pack-reused 234598 (from 2)
# Receiving objects: 100% (234786/234786), 219.29 MiB | 23.30 MiB/s, done.
# Resolving deltas: 100% (214410/214410), done.
# Updating files: 100% (44202/44202), done.

# %%
# %cd /content/roboto-3-classic
# Out:
# /content/roboto-3-classic

# %%
# !pip install .

# %%
# !pip install -r requirements.txt

# %%
# !sh sources/build.sh

# %% [markdown]
# ## Take at least 5 fonts for each codepoint

# %%
import json

# Set threshold
MAX_FONTS_PER_CODEPOINT = 5

# Trim to at most 5 fonts per codepoint
trimmed_supported_fonts_mapping = {
    cp: fonts[:MAX_FONTS_PER_CODEPOINT]
    for cp, fonts in supported_fonts_mapping.items()
}

# Save to JSON file
json_filename = "supported_fonts_mapping_trimmed.json"

with open(json_filename, 'w', encoding='utf-8') as json_file:
    json.dump(trimmed_supported_fonts_mapping, json_file, indent=4, ensure_ascii=False)

print(f"Supported fonts mapping saved to {json_filename}")
# Out:
# Supported fonts mapping saved to supported_fonts_mapping_trimmed.json

# %%
trimmed_supported_fonts_mapping["U+00A1"]
# Out:
# ['Noto Sans Tifinagh SIL',
#  'Noto Sans Mahajani',
#  'Noto Sans Sundanese',
#  'Noto Kufi Arabic',
#  'Noto Sans Soyombo']

# %%
# !wget https://unifoundry.com/pub/unifont/unifont-16.0.04/font-builds/unifont-16.0.04.otf -O /content/unifont-16.0.04.otf

# !mkdir -p /usr/share/fonts/truetype/custom
# !cp /content/unifont-16.0.04.otf /usr/share/fonts/truetype/custom/
# !fc-cache -fv
# !fc-list | grep -i unifont

# %% [markdown]
# ### Install Qahirah Library for drawing the characters

# %%
# !apt-get -y update
# !apt-get -y install libfreetype6 libcairo2 libsm6 libxext6 libfontconfig1 libxrender1 fontconfig libgl1-mesa-glx unzip
# !wget https://gitlab.com/ldo/qahirah/-/archive/master/qahirah-master.tar.gz
# !tar -xvzf /content/qahirah-master.tar.gz
# !mv /content/qahirah-master /content/qahirah
# %cd /content/qahirah
# !pip install .
# %cd ..

# %% [markdown]
# ### Install Python Freetype

# %%
# !wget https://gitlab.com/ldo/python_freetype/-/archive/master/python_freetype-master.tar.gz
# !tar -xvzf /content/python_freetype-master.tar.gz
# !mv /content/python_freetype-master /content/python_freetype
# %cd /content/python_freetype
# !pip install .
# %cd ..

# %% [markdown]
# ### Custom VisualGenerator Class inherited from the VisualGenerator class.

# %%
from vis_gen import VisualGenerator
import qahirah as qah
from qahirah import CAIRO, Colour, Vector
from tqdm import tqdm

class CustomVisualGenerator(VisualGenerator):
  def generate_dataset_from_json_file(self, file_path, font_styles, antialiases):
    """
      Generates a dataset of rendered images from a JSON file mapping Unicode codepoints to font names.

      Args:
          file_path (str): Path to the JSON file containing a dictionary where keys are codepoints (e.g., "U+0041")
                          and values are lists of font names that support rendering that codepoint.
          font_styles (List[str]): A list of font style names (e.g., ["Regular", "Bold", "Italic"]) to use for rendering.
          antialiases (List[str]): A list of antialiasing options (e.g., ["Default", "None", "Grayscale"]) to apply
                                  during rendering.

      This method processes each codepoint and renders it using each combination of font name, style, and antialiasing
      setting provided. The rendered images are saved to the output directory specified in the class.

      Note:
          - Codepoints that cause errors during rendering are skipped with a warning.
          - This function assumes the fonts are already installed and accessible by name.
          - Output directory will be created if it doesn't exist.
    """
    out_dir_abs = self._get_out_dir_abs_and_check()

    with open(file_path, 'r') as f:
      trimmed_supported_fonts_mapping = json.load(f)

    print(f"Processing {len(trimmed_supported_fonts_mapping)} codepoints...")
    for codepoint, font_names in tqdm(trimmed_supported_fonts_mapping.items(), desc="Codepoints"):
      try:
        code_point = chr(int('0x' + codepoint[2:], 16))
        self.generate_dataset_from_list([code_point], font_names, font_styles, antialiases)
      except Exception as e:
        print(f"Error processing codepoint {codepoint}: {e}")
        continue

    self._check_out_dir = True

  def generate_dataset_from_list(self, code_points, font_names, font_styles, antialiases):
    # Check if out_dir exists and create if not
    out_dir_abs = self._get_out_dir_abs_and_check()

    for font_name in font_names:
      self.font_name = font_name
      for font_style in font_styles:
        self.font_style = font_style
        for antialias in antialiases:
          self.antialias = antialias
          self.visualize_list(code_points)

    # Flag flipped to False in self._get_out_dir_abs_and_check
    self._check_out_dir = True

  def visualize_list(self, code_points, x=None, y=None):
    # Check if out_dir exists and create if not
    out_dir_abs = self._get_out_dir_abs_and_check()

    # Visualize list of code points
    for idx, code_point in enumerate(code_points):
        self.visualize_single(code_point, False, x=x, y=y)

    # Flag flipped to False in self._get_out_dir_abs_and_check
    self._check_out_dir = True

# %%
# Remove the old datasets to make space
# !rm -rf /content/data_* data_*.zip

# %%
from vis_gen import VisualGenerator
import os
import json

vg = CustomVisualGenerator(font_name='Noto Sans')

vg.image_size = 42
vg.font_size = 40
vg.out_dir = 'data_custom'
mapping_file='/content/supported_fonts_mapping_trimmed.json'

vg.generate_dataset_from_json_file(mapping_file, ['Bold','Medium','Regular','DemiLight','Light','Thin'],['Default','None'])

# %%
# !zip -r data_custom.zip /content/data_custom

# %% [markdown]
# ## Transfer the data to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/supported_fonts_mapping_combined.json /content/drive/MyDrive/Unicode_GSoC_Colab

# %%
# !cp /content/supported_fonts_mapping_trimmed.json /content/drive/MyDrive/Unicode_GSoC_Colab
